# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %%
type(text)
# Out:
# str

# %%
len(text)
# Out:
# 100000000

# %%
text[:1000]
# Out:
# ' anarchism originated as a term of abuse first used against early working class radicals including the diggers of the english revolution and the sans culottes of the french revolution whilst the term is still used in a pejorative way to describe any act that used violent means to destroy the organization of society it has also been taken up as a positive label by self defined anarchists the word anarchism is derived from the greek without archons ruler chief king anarchism as a political philosophy is the belief that rulers are unnecessary and should be abolished although there are differing interpretations of what this means anarchism also refers to related social movements that advocate the elimination of authoritarian institutions particularly the state the word anarchy as most anarchists use it does not imply chaos nihilism or anomie but rather a harmonious anti authoritarian society in place of what are regarded as authoritarian political structures and coercive economic instituti'

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %%
print(words[:200])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst', 'the', 'term', 'is', 'still', 'used', 'in', 'a', 'pejorative', 'way', 'to', 'describe', 'any', 'act', 'that', 'used', 'violent', 'means', 'to', 'destroy', 'the', 'organization', 'of', 'society', 'it', 'has', 'also', 'been', 'taken', 'up', 'as', 'a', 'positive', 'label', 'by', 'self', 'defined', 'anarchists', 'the', 'word', 'anarchism', 'is', 'derived', 'from', 'the', 'greek', 'without', 'archons', 'ruler', 'chief', 'king', 'anarchism', 'as', 'a', 'political', 'philosophy', 'is', 'the', 'belief', 'that', 'rulers', 'are', 'unnecessary', 'and', 'should', 'be', 'abolished', 'although', 'there', 'are', 'differing', 'interpretations', 'of', 'what', 'this', 'means', 'anarchism', 'also', 'refers', 'to', 'related', 'social', 'movements', 'that', 'advocate', 'the', 'elimination', 'of', 'authoritarian', 'institutions', 'particularly', 'the', 'state', 'the', 'word', 'anarchy', 'as', 'most', 'anarchists', 'use', 'it', 'does', 'not', 'imply', 'chaos', 'nihilism', 'or', 'anomie', 'but', 'rather', 'a', 'harmonious', 'anti', 'authoritarian', 'society', 'in', 'place', 'of', 'what', 'are', 'regarded', 'as', 'authoritarian', 'political', 'structures', 'and', 'coercive', 'economic', 'institutions', 'anarchists', 'advocate', 'social', 'relations', 'based', 'upon', 'voluntary', 'association', 'of', 'autonomous', 'individuals', 'mutual', 'aid', 'and', 'self', 'governance', 'while', 'anarchism', 'is', 'most', 'easily', 'defined', 'by', 'what', 'it', 'is', 'against', 'anarchists', 'also', 'offer', 'positive', 'visions', 'of', 'what', 'they', 'believe', 'to', 'be', 'a', 'truly', 'free', 'society']

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %%
[int_to_vocab[i] for i in range(10)]
# Out:
# ['the', 'of', 'and', 'one', 'in', 'a', 'to', 'zero', 'nine', 'two']

# %%
vocab_to_int['the'], vocab_to_int['person']
# Out:
# (0, 397)

# %%
int_words[:15]
# Out:
# [5235, 3082, 11, 5, 194, 1, 3136, 45, 58, 155, 127, 741, 476, 10597, 133]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
## Your code here

import math

def get_discard_prob(freq, threshold):
    return 1 - math.sqrt(threshold / freq)

# %%
import matplotlib.pyplot as plt
plt.plot(
    [i * 0.01 for i in range(1, 100, 1)], 
    [get_discard_prob(i * 0.01, 0.2) for i in range(1, 100, 1)]
)
plt.show()

# %%
from collections import Counter

total_words_count = len(int_words)
int_words_count = Counter(int_words)

# %%
total_words_count
# Out:
# 16680599

# %%
int_words_count[5233]
# Out:
# 303

# %%
int_words_count[5233]  / total_words_count
# Out:
# 1.8164815304294527e-05

# %%
10e-5
# Out:
# 0.0001

# %%
import random

min_discard_prob = 1e-5  # 10e-5

train_words = []
for int_word in int_words:
    count = int_words_count[int_word] 
    freq = count / total_words_count
    discard_prob = get_discard_prob(freq, min_discard_prob)
#     print('int_word=', int_word, ', ', int_to_vocab[int_word], ', freq=', freq, ', discard_prob=', discard_prob)
    
    if random.random() <= discard_prob:
        # discard word
#         print('drop int_word')
        pass
    else:
        # keep word
        train_words.append(int_word)

# %%
total_words_count, len(train_words)
# Out:
# (16680599, 4627016)

# %%
int_words[:10]
# Out:
# [5235, 3082, 11, 5, 194, 1, 3136, 45, 58, 155]

# %%
train_words[:10] # The final subsampled word list
# Out:
# [5235, 194, 3136, 10597, 0, 27455, 15111, 62204, 854, 3583]

# %%
int_to_vocab[3080], int_to_vocab[11], int_to_vocab[5], int_to_vocab[194], int_to_vocab[1], int_to_vocab[3133], int_to_vocab[45], int_to_vocab[58]
# Out:
# ('matrix', 'as', 'a', 'term', 'of', 'recipient', 'first', 'used')

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
[0, 1, 2, 3][4:8]
# Out:
# []

# %%
random.randint(1, 5)
# Out:
# 1

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''    
    # Your code here    
    r = random.randint(1, window_size)   
    
    left_idx = idx - r
    if left_idx < 0:
        left_idx = 0
        
    target = words[left_idx: idx] + words[idx + 1 : idx + 1 + r]        
    return list(set(target))

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words) // batch_size
    
    # only full batches
    words = words[: n_batches * batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx: idx + batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x] * len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None])
    labels = tf.placeholder(tf.int32, [None, 1])

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200 # Number of embedding features 

with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform([n_vocab, n_embedding], minval=-1, maxval=1))  # create embedding weight matrix here
    embed = tf.nn.embedding_lookup(embedding, inputs)  # use tf.nn.embedding_lookup to get the hidden layer output

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    # NOTE: pay attention, the dimension here is transposed
    softmax_w = tf.Variable(tf.truncated_normal([n_vocab, n_embedding], stddev=0.1)) # create softmax weight matrix here
    softmax_b = tf.Variable(tf.zeros(n_vocab))  # create softmax biases here
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(
        softmax_w,
        softmax_b,
        labels,
        embed,
        n_sampled,
        n_vocab,
    )
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
random.sample(range(10), 4)
# Out:
# [0, 7, 8, 5]

# %%
# import random

# ## From Thushan Ganegedara's implementation
# valid_size = 16 # Random set of words to evaluate similarity on.
# valid_window = 100
# # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
# valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
# valid_examples = np.append(
#     valid_examples, 
#     random.sample(range(1000,1000+valid_window), valid_size//2)
# )

valid_examples = [
    vocab_to_int[i] for i in [
        'person', 'people', 'human', 'boy', 'girl', 'man', 'woman', 'baby', 'father', 'mother', 
        'king', 'queen',  'prince', 'princess', 'general', 'soldier',
        'dog', 'pig', 'cat', 'mouse', 'fish', 'bird', 'eagle', 'pigeon',
        'tree', 'flower', 'grass', 'apple', 'orange', 'grape',
        'red', 'green', 'yellow', 'blue', 'dark',
        'sun', 'earth', 'mars', 'moon', 'universe',
        'water', 'fire', 'stone',
        'run', 'walk', 'crawl', 'jump', 'jog',
        'food', 'meal', 'breakfast', 'lunch', 'dinner', 'meat', 'rice', 'vegetable',
        'love', 'hate', 'kiss', 'kill', 'war', 'peace',
        'machine',        
    ]
]

valid_examples
# Out:
# [397,
#  82,
#  224,
#  1497,
#  2589,
#  242,
#  1011,
#  3431,
#  408,
#  729,
#  186,
#  902,
#  1060,
#  3421,
#  152,
#  3084,
#  1900,
#  9107,
#  2601,
#  2788,
#  1525,
#  2969,
#  5991,
#  15632,
#  1237,
#  5521,
#  6013,
#  1218,
#  2929,
#  15652,
#  411,
#  828,
#  2456,
#  758,
#  1302,
#  903,
#  329,
#  2374,
#  949,
#  1008,
#  287,
#  670,
#  1481,
#  533,
#  3194,
#  27602,
#  4519,
#  35657,
#  641,
#  7172,
#  11851,
#  14838,
#  9393,
#  2912,
#  2972,
#  8216,
#  610,
#  5544,
#  7972,
#  2249,
#  83,
#  790,
#  798]

# %%
with train_graph.as_default():
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints
# Out:
# mkdir: cannot create directory ‘checkpoints’: File exists

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 6
batch_size = 1000
window_size = 10

# %%
batches_per_epoch = len(train_words) / batch_size
batches_per_epoch
# Out:
# 4627.016

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
                
            if iteration % 2000 == 0:  # if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
            
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6524 0.0400 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.6031 0.0369 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.5038 0.0373 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.6315 0.0370 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.5253 0.0370 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5359 0.0370 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5700 0.0369 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5235 0.0371 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4450 0.0369 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4408 0.0371 sec/batch
# Nearest to been: inen, yangtze, op, bartholomew, afar, forgets, anthems, spinner,
# Nearest to about: filming, kylix, detects, laconic, britons, framing, anions, clerical,
# Nearest to by: flashlight, abdelkader, rebooted, outbound, heinz, paradoxically, typifies, merthyr,
# Nearest to that: environment, zimbabwe, transfection, rabies, vaccination, fari, sor, failure,
# Nearest to such: sequential, graduation, yong, midrange, ginsberg, cerrado, radiology, hus,
# Nearest to or: apicomplexa, insertion, lalr, observational, oregon, flashing, adema, title,
# Nearest to to: nepal, sulfur, vasquez, subjecting, rhodium, lamarckian, section, haircut,
# Nearest to the: talking, sympathetically, hawaii, select, unlucky, fru, mapping, calc,
# Nearest to hit: whence, replacing, throats, leading, lito, palestinians, group, poststructuralist,
# Nearest to pressure: transhumanist, outdoors, yassin, wrestling, oscars, eleusis, kubrick, frisian,
# Nearest to experience: takeda, sobib, vasco, newspaperman, angelus, hoya, epoch, phenomenally,
# Nearest to stage: dietmar, silberman, hissarlik, williamite, partito, polynomial, noticed, dosomething,
# Nearest to issue: ramesh, roamed, carne, resize, whewell, ieoh, zavos, waterfall,
# Nearest to placed: fleurs, anthroposophy, phrases, autonomic, adamantium, glaciated, bobwhite, riigikogu,
# Nearest to test: fart, moderne, hampstead, literate, oswego, ender, monte, associated,
# Nearest to mainly: consulate, jamil, enquirer, rite, erat, object, hongkong, mere,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4337 0.0383 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3855 0.0373 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3512 0.0371 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2111 0.0370 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.1797 0.0373 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1690 0.0371 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.1060 0.0373 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0778 0.0372 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 4.9960 0.0370 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9964 0.0375 sec/batch
# Nearest to been: yangtze, cocoa, romantic, bartholomew, spinner, anthems, palmerston, wall,
# Nearest to about: filming, britons, immediately, milestones, fast, kylix, detects, stamp,
# Nearest to by: flashlight, last, longer, cultural, kingdom, rebooted, accepted, arguments,
# Nearest to that: environment, zimbabwe, transfection, failure, note, reported, voice, uncertainties,
# Nearest to such: sequential, graduation, targeted, theoretical, yong, appointed, vast, hus,
# Nearest to or: title, flashing, oregon, cocoa, compiler, simple, instance, insertion,
# Nearest to to: nepal, view, suggests, sulfur, act, section, namely, vasquez,
# Nearest to the: select, mapping, talking, considerably, nature, unlucky, sympathetically, hawaii,
# Nearest to hit: leading, whence, replacing, group, palestinians, lito, striped, covered,
# Nearest to pressure: frisian, outdoors, westminster, s, kubrick, oscars, transhumanist, eleusis,
# Nearest to experience: vasco, photographer, epoch, phenomenally, monoamine, celtic, clarity, historically,
# Nearest to stage: dietmar, occurred, silberman, polynomial, faith, hissarlik, trained, guanine,
# Nearest to issue: ramesh, roamed, theater, carnage, carne, by, resize, emphasizing,
# Nearest to placed: phrases, fleurs, universal, chaos, eurozone, shall, adamantium, anthroposophy,
# Nearest to test: moderne, literate, associated, hampstead, monte, oswego, fart, ender,
# Nearest to mainly: consulate, object, mere, rite, jamil, feuds, replace, re,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9245 0.0388 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.9021 0.0371 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.9001 0.0371 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8708 0.0371 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8069 0.0369 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8066 0.0371 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.8034 0.0370 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.8081 0.0372 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7697 0.0376 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7707 0.0374 sec/batch
# Nearest to been: romantic, bartholomew, yangtze, cocoa, spinner, slugger, wall, op,
# Nearest to about: filming, clerical, milestones, britons, detects, noel, kylix, stamp,
# Nearest to by: flashlight, last, heinz, demand, arguments, cultural, paradoxically, sudan,
# Nearest to that: environment, uncertainties, vaccination, zimbabwe, reported, transfection, failure, speculation,
# Nearest to such: sequential, graduation, targeted, theoretical, yong, petty, vast, mulder,
# Nearest to or: oregon, insertion, flashing, observational, gifts, title, obligation, wire,
# Nearest to to: nepal, view, sulfur, act, vasquez, suggests, maintains, namely,
# Nearest to the: select, mapping, considerably, talking, famine, lust, nature, unlucky,
# Nearest to hit: whence, leading, replacing, performances, lito, palestinians, wealthiest, covered,
# Nearest to pressure: outdoors, frisian, oscars, wrestling, kubrick, westminster, transhumanist, galactus,
# Nearest to experience: epoch, vasco, photographer, sobib, phenomenally, monoamine, clarity, tract,
# Nearest to stage: dietmar, faith, occurred, silberman, noticed, polynomial, hissarlik, mauryan,
# Nearest to issue: ramesh, roamed, theater, os, carnage, avatars, filming, carne,
# Nearest to placed: phrases, fleurs, eurozone, chaos, universal, autonomic, anthroposophy, shall,
# Nearest to test: literate, moderne, fart, monte, hampstead, municipalities, associated, oswego,
# Nearest to mainly: consulate, object, jamil, mere, rite, feuds, aligned, consulted,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7800 0.0387 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7455 0.0373 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7305 0.0379 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.6982 0.0374 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7395 0.0375 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.6898 0.0375 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.7150 0.0375 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7208 0.0373 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.6995 0.0375 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6708 0.0371 sec/batch
# Nearest to been: bartholomew, romantic, spinner, yangtze, afar, slugger, forgets, wall,
# Nearest to about: filming, detects, framing, noel, clerical, milestones, kylix, britons,
# Nearest to by: flashlight, heinz, abdelkader, last, demand, paradoxically, rebooted, sudan,
# Nearest to that: environment, uncertainties, vaccination, fari, failure, reported, zimbabwe, transfection,
# Nearest to such: sequential, graduation, theoretical, yong, targeted, ginsberg, overturning, mulder,
# Nearest to or: insertion, observational, flashing, gifts, lalr, oregon, obligation, calvinist,
# Nearest to to: view, nepal, act, maintains, vasquez, kelvin, sulfur, mcgraw,
# Nearest to the: select, mapping, famine, considerably, lust, talking, goodbye, referenda,
# Nearest to hit: whence, performances, wealthiest, throats, lito, replacing, leading, palestinians,
# Nearest to pressure: outdoors, oscars, frisian, wrestling, transhumanist, kubrick, eleusis, erythrocytes,
# Nearest to experience: vasco, epoch, phenomenally, takeda, sobib, monoamine, angelus, hardness,
# Nearest to stage: dietmar, silberman, mauryan, noticed, hissarlik, occurred, williamite, faith,
# Nearest to issue: ramesh, roamed, theater, zavos, filming, intuitions, os, carne,
# Nearest to placed: phrases, fleurs, eurozone, autonomic, encyclopedias, anthroposophy, queueing, chaos,
# Nearest to test: moderne, monte, literate, fart, hampstead, levee, municipalities, oswego,
# Nearest to mainly: consulate, rite, jamil, feuds, object, mere, cyclic, consulted,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6816 0.0384 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6799 0.0374 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6174 0.0375 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6420 0.0376 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6596 0.0375 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6278 0.0379 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.5878 0.0280 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5261 0.0375 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.4907 0.0375 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.4957 0.0372 sec/batch
# Nearest to been: afar, forgets, bartholomew, levellers, slugger, romantic, yangtze, cocoa,
# Nearest to about: filming, framing, detects, milestones, blaue, anions, focussing, noel,
# Nearest to by: flashlight, heinz, abdelkader, paradoxically, cimmerian, rebooted, typifies, arguments,
# Nearest to that: environment, uncertainties, vaccination, speculation, transfection, fari, failure, reported,
# Nearest to such: sequential, theoretical, targeted, graduation, yong, ebooks, overturning, ginsberg,
# Nearest to or: insertion, observational, flashing, obligation, adema, mirroring, lalr, apicomplexa,
# Nearest to to: view, nepal, act, vasquez, maintains, referees, fallen, suggests,
# Nearest to the: select, mapping, famine, considerably, barbaric, lust, unlucky, salamis,
# Nearest to hit: performances, whence, lito, throats, wealthiest, replacing, palestinians, leading,
# Nearest to pressure: outdoors, oscars, frisian, transhumanist, kubrick, wrestling, shewa, analysis,
# Nearest to experience: phenomenally, takeda, vasco, sobib, epoch, angelus, hardness, newspaperman,
# Nearest to stage: dietmar, silberman, hissarlik, noticed, mediocrity, mauryan, occurred, expeditionary,
# Nearest to issue: ramesh, roamed, zavos, theater, filming, intuitions, whewell, avatars,
# Nearest to placed: phrases, fleurs, autonomic, eurozone, anthroposophy, encyclopedias, queueing, glaciated,
# Nearest to test: moderne, developer, literate, hampstead, fart, monte, levee, oswego,
# Nearest to mainly: consulate, jamil, rite, cyclic, object, mere, feuds, consulted,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.5068 0.0385 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.4844 0.0374 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4689 0.0373 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5264 0.0376 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.5061 0.0376 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4668 0.0377 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4396 0.0375 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.3960 0.0373 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4373 0.0376 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4452 0.0375 sec/batch
# Nearest to been: forgets, afar, bartholomew, slugger, ramesses, yangtze, marshy, levellers,
# Nearest to about: detects, filming, milestones, focussing, anions, blaue, framing, accrued,
# Nearest to by: flashlight, paradoxically, heinz, longer, cimmerian, rebooted, last, abdelkader,
# Nearest to that: environment, vaccination, uncertainties, failure, transfection, fari, speculation, simpler,
# Nearest to such: sequential, theoretical, targeted, overturning, yong, ebooks, graduation, biochemical,
# Nearest to or: insertion, observational, apicomplexa, crystals, stocks, mirroring, obligation, lalr,
# Nearest to to: sulfur, ermine, vasquez, view, referees, nepal, suggests, fallen,
# Nearest to the: select, mapping, famine, salamis, considerably, unlucky, stylistically, lust,
# Nearest to hit: performances, whence, throats, palestinians, replacing, leading, lito, babe,
# Nearest to pressure: outdoors, oscars, frisian, transhumanist, wrestling, kubrick, analysis, shewa,
# Nearest to experience: phenomenally, takeda, epoch, sobib, encyclopedists, vasco, hardness, angelus,
# Nearest to stage: dietmar, silberman, noticed, hissarlik, mediocrity, occurred, mauryan, expeditionary,
# Nearest to issue: ramesh, roamed, zavos, intuitions, theater, preemptive, ieoh, whewell,
# Nearest to placed: phrases, fleurs, anthroposophy, eurozone, autonomic, queueing, glaciated, encyclopedias,
# Nearest to test: moderne, developer, fart, hampstead, literate, levee, monte, charcot,
# Nearest to mainly: consulate, cyclic, rite, jamil, resulted, feuds, spanned, consulted,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4441 0.0383 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4112 0.0374 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4455 0.0373 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.3836 0.0372 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4301 0.0374 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4207 0.0374 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3865 0.0374 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3706 0.0375 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4176 0.0377 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3729 0.0376 sec/batch
# Nearest to been: forgets, afar, levellers, yangtze, inen, romantic, spinner, marshy,
# Nearest to about: detects, milestones, filming, blaue, focussing, anions, framing, florentines,
# Nearest to by: flashlight, paradoxically, legislatures, cimmerian, typifies, abdelkader, heinz, cour,
# Nearest to that: vaccination, environment, uncertainties, speculation, lobbying, proponents, transfection, violation,
# Nearest to such: sequential, theoretical, targeted, biochemical, overturning, yong, ebooks, cpt,
# Nearest to or: insertion, observational, lalr, instance, flashing, apicomplexa, calvinist, obligation,
# Nearest to to: salmi, referees, maneuvers, maintains, view, act, fallen, hag,
# Nearest to the: select, mapping, lust, famine, distinguishing, salamis, unlucky, dispose,
# Nearest to hit: performances, whence, throats, ride, casc, picks, leading, fawlty,
# Nearest to pressure: outdoors, oscars, frisian, wrestling, aromas, transhumanist, joukahainen, nadezhda,
# Nearest to experience: encyclopedists, epoch, sobib, phenomenally, vasco, takeda, twickenham, angelus,
# Nearest to stage: dietmar, silberman, occurred, noticed, mauryan, mediocrity, hissarlik, expeditionary,
# Nearest to issue: ramesh, zavos, roamed, ieoh, intuitions, carne, preemptive, theater,
# Nearest to placed: phrases, fleurs, queueing, anthroposophy, glaciated, summands, eurozone, autonomic,
# Nearest to test: moderne, developer, fart, literate, stenosis, hampstead, oswego, brothel,
# Nearest to mainly: consulate, jamil, rite, cyclic, spanned, resulted, coastal, feuds,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3817 0.0389 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3961 0.0376 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3785 0.0379 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3798 0.0376 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.4011 0.0378 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3407 0.0376 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3843 0.0376 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3702 0.0377 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3119 0.0378 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3338 0.0377 sec/batch
# Nearest to been: forgets, levellers, afar, debate, gory, suggested, romantic, spinner,
# Nearest to about: milestones, detects, focussing, filming, blaue, summarizes, anions, hires,
# Nearest to by: flashlight, paradoxically, cimmerian, legislatures, cour, abdelkader, gruyter, heinz,
# Nearest to that: uncertainties, vaccination, environment, claimants, speculation, violation, fari, prohibited,
# Nearest to such: sequential, theoretical, targeted, biochemical, radiology, graduation, ebooks, yong,
# Nearest to or: insertion, observational, lalr, stocks, obligation, marginal, ignorance, calvinist,
# Nearest to to: nepal, maintains, salmi, vasquez, referees, view, fallen, diversion,
# Nearest to the: select, of, dispose, mapping, famine, and, referenda, backfield,
# Nearest to hit: performances, throats, picks, ride, fawlty, whence, babe, leading,
# Nearest to pressure: outdoors, transhumanist, oscars, aromas, wrestling, frisian, joukahainen, secretes,
# Nearest to experience: encyclopedists, sobib, epoch, takeda, phenomenally, angelus, vasco, newspaperman,
# Nearest to stage: dietmar, silberman, occurred, mediocrity, mauryan, hissarlik, noticed, tangle,
# Nearest to issue: zavos, roamed, ramesh, ieoh, intuitions, preemptive, valuation, theater,
# Nearest to placed: autonomic, phrases, queueing, glaciated, fleurs, eurozone, plucking, anthroposophy,
# Nearest to test: developer, moderne, fart, stenosis, hampstead, revoluci, captions, relented,
# Nearest to mainly: consulate, jamil, spanned, resulted, consulted, cyclic, rite, coastal,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3339 0.0388 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.2772 0.0376 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3815 0.0375 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3982 0.0373 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3869 0.0371 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2936 0.0375 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.3240 0.0370 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3319 0.0373 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2143 0.0372 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.2909 0.0373 sec/batch
# Nearest to been: forgets, levellers, debate, afar, suggested, romantic, spinner, catastrophe,
# Nearest to about: milestones, focussing, filming, detects, kimmel, blaue, hauling, summarizes,
# Nearest to by: flashlight, paradoxically, cimmerian, gruyter, abdelkader, cour, sudan, hammerheads,
# Nearest to that: uncertainties, vaccination, environment, claimants, clarify, fari, speculation, inexplicably,
# Nearest to such: sequential, theoretical, targeted, biochemical, radiology, yong, graduation, ebooks,
# Nearest to or: insertion, observational, lalr, ignorance, marginal, obligation, bjarne, instance,
# Nearest to to: maintains, fallen, salmi, diversion, vasquez, impediments, outlandish, nepal,
# Nearest to the: famine, of, select, and, mapping, salamis, backfield, in,
# Nearest to hit: performances, picks, ride, fawlty, throats, babe, whence, casc,
# Nearest to pressure: outdoors, transhumanist, oscars, everest, aromas, erythrocytes, frisian, secretes,
# Nearest to experience: sobib, encyclopedists, takeda, epoch, phenomenally, mental, newspaperman, treated,
# Nearest to stage: dietmar, silberman, mediocrity, occurred, tangle, melodic, hissarlik, noticed,
# Nearest to issue: zavos, roamed, ramesh, ieoh, preemptive, intuitions, revisionist, theater,
# Nearest to placed: autonomic, glaciated, jubal, eurozone, coincide, queueing, plucking, fleurs,
# Nearest to test: developer, fart, stenosis, revoluci, relented, urgent, moderne, oswego,
# Nearest to mainly: consulate, jamil, spanned, coastal, cyclic, resulted, rite, mangrove,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.3197 0.0383 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.2718 0.0374 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3308 0.0177 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2579 0.0372 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.1998 0.0372 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2048 0.0374 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2350 0.0376 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.1913 0.0373 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2324 0.0374 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1855 0.0372 sec/batch
# Nearest to been: forgets, levellers, catastrophe, afar, suggested, debate, gabba, pares,
# Nearest to about: detects, milestones, focussing, anions, summarizes, hires, hauling, sea,
# Nearest to by: flashlight, paradoxically, cour, abdelkader, sudan, typifies, hammerheads, oppositional,
# Nearest to that: uncertainties, vaccination, environment, speculation, claimants, inexplicably, fari, violation,
# Nearest to such: sequential, theoretical, targeted, ebooks, radiology, biochemical, yong, overturning,
# Nearest to or: insertion, lalr, observational, obligation, bjarne, stocks, apicomplexa, predicates,
# Nearest to to: fallen, maintains, salmi, diversion, outlandish, nami, impediments, maneuvers,
# Nearest to the: of, famine, in, and, sfg, unlucky, bibles, city,
# Nearest to hit: performances, picks, ride, roster, babe, cubs, fawlty, runners,
# Nearest to pressure: outdoors, everest, aromas, transhumanist, joukahainen, surrounding, mild, wrestling,
# Nearest to experience: sobib, encyclopedists, mental, unconscious, newspaperman, epoch, treated, takeda,
# Nearest to stage: dietmar, silberman, occurred, noticed, mediocrity, appreciably, mileage, tangle,
# Nearest to issue: zavos, roamed, ramesh, ieoh, intuitions, preemptive, revisionist, xcode,
# Nearest to placed: glaciated, autonomic, toed, coincide, plucking, going, queueing, eurozone,
# Nearest to test: developer, relented, flintoff, fart, revoluci, oswego, urgent, stenosis,
# Nearest to mainly: consulate, jamil, spanned, coastal, resulted, rite, mangrove, polonia,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2315 0.0385 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2031 0.0376 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2246 0.0377 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1495 0.0373 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1988 0.0373 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1634 0.0373 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1375 0.0375 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1530 0.0378 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.2131 0.0374 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1872 0.0377 sec/batch
# Nearest to been: forgets, levellers, catastrophe, suggested, afar, debate, gabba, yangtze,
# Nearest to about: detects, milestones, focussing, miracleman, kimmel, filming, summarizes, anions,
# Nearest to by: flashlight, paradoxically, cour, typifies, abdelkader, oppositional, xvi, propylene,
# Nearest to that: uncertainties, vaccination, environment, indiscernibles, inexplicably, fari, transfection, speculation,
# Nearest to such: sequential, targeted, theoretical, biochemical, radiology, overturning, ebooks, yong,
# Nearest to or: insertion, instance, lalr, observational, dots, obligation, upside, transmembrane,
# Nearest to to: fallen, salmi, namely, referees, spoiler, aegon, nami, outlandish,
# Nearest to the: of, in, sfg, unlucky, famine, dispose, bibles, forehand,
# Nearest to hit: performances, picks, ride, cubs, babe, roster, angry, fibreglass,
# Nearest to pressure: outdoors, aromas, mild, joukahainen, everest, erythrocytes, secretes, increases,
# Nearest to experience: encyclopedists, sobib, unconscious, mental, newspaperman, epoch, phenomenally, treated,
# Nearest to stage: dietmar, silberman, mileage, mediocrity, forefinger, tangle, appreciably, occurred,
# Nearest to issue: zavos, roamed, ramesh, ieoh, preemptive, intuitions, valuation, revisionist,
# Nearest to placed: glaciated, autonomic, toed, waist, coincide, plucking, queueing, happens,
# Nearest to test: developer, flintoff, fart, urgent, oswego, revoluci, lps, stenosis,
# Nearest to mainly: spanned, consulate, jamil, resulted, coastal, mangrove, abbasids, areas,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1885 0.0385 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2106 0.0374 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.2016 0.0377 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1430 0.0373 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1927 0.0375 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1917 0.0378 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.1888 0.0375 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1898 0.0371 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1382 0.0375 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1735 0.0376 sec/batch
# Nearest to been: levellers, forgets, debate, suggested, catastrophe, gabba, romantic, spinner,
# Nearest to about: detects, milestones, miracleman, focussing, kimmel, anions, hauling, filming,
# Nearest to by: flashlight, paradoxically, cour, oppositional, gruyter, famous, merthyr, bagley,
# Nearest to that: uncertainties, indiscernibles, vaccination, inexplicably, environment, intelligencer, speculation, claimants,
# Nearest to such: sequential, theoretical, targeted, biochemical, radiology, ebooks, overturning, cpt,
# Nearest to or: insertion, obligation, instance, lalr, upside, stocks, dots, rudimentary,
# Nearest to to: referees, fallen, salmi, maintains, nami, spoiler, namely, outlandish,
# Nearest to the: of, sfg, in, kolbin, diatoms, bibles, mapping, backfield,
# Nearest to hit: performances, picks, ride, throats, leading, babe, angry, hits,
# Nearest to pressure: outdoors, aromas, everest, joukahainen, mild, erythrocytes, surrounding, secretes,
# Nearest to experience: encyclopedists, sobib, newspaperman, phenomenally, mental, twickenham, unconscious, melded,
# Nearest to stage: dietmar, silberman, mileage, occurred, forefinger, mediocrity, melodic, trained,
# Nearest to issue: zavos, ramesh, roamed, ieoh, preemptive, intuitions, hurdle, publication,
# Nearest to placed: glaciated, autonomic, waist, plucking, going, toed, happens, riigikogu,
# Nearest to test: developer, flintoff, revoluci, fart, stenosis, urgent, relented, oswego,
# Nearest to mainly: spanned, jamil, consulate, coastal, resulted, rite, speakers, abbasids,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.2090 0.0384 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1855 0.0375 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1661 0.0374 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1999 0.0376 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1382 0.0377 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1636 0.0372 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1413 0.0371 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1247 0.0377 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.2042 0.0376 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.2090 0.0375 sec/batch
# Nearest to been: levellers, debate, forgets, suggested, gabba, pares, romantic, catastrophe,
# Nearest to about: milestones, kimmel, miracleman, hauling, monthly, peninsular, detects, hires,
# Nearest to by: oppositional, paradoxically, cour, gruyter, of, abdelkader, flashlight, typifies,
# Nearest to that: uncertainties, indiscernibles, inexplicably, claimants, vii, vaccination, intelligencer, chola,
# Nearest to such: sequential, targeted, theoretical, biochemical, yong, radiology, overturning, graduation,
# Nearest to or: insertion, obligation, instance, archbishopric, dots, bjarne, holbein, lalr,
# Nearest to to: tsar, fallen, maintains, vasquez, nami, chavez, salmi, deciding,
# Nearest to the: of, kolbin, and, in, famine, bibles, adventists, sfg,
# Nearest to hit: performances, picks, babe, angry, holly, roster, ride, hits,
# Nearest to pressure: outdoors, everest, joukahainen, yassin, erythrocytes, oscars, urge, transhumanist,
# Nearest to experience: encyclopedists, sobib, phenomenally, newspaperman, takeda, melded, twickenham, surveyed,
# Nearest to stage: dietmar, silberman, occurred, mileage, mediocrity, forefinger, mauryan, servicemales,
# Nearest to issue: zavos, ramesh, roamed, ieoh, preemptive, publication, intuitions, revisionist,
# Nearest to placed: autonomic, glaciated, going, eurozone, toed, coincide, fleurs, riigikogu,
# Nearest to test: developer, flintoff, stenosis, revoluci, relented, urgent, fart, oswego,
# Nearest to mainly: spanned, jamil, consulate, abbasids, polonia, rite, resulted, kine,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2457 0.0387 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1506 0.0378 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1158 0.0376 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1687 0.0375 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0301 0.0375 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1451 0.0377 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1552 0.0377 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1234 0.0380 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1782 0.0078 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1150 0.0378 sec/batch
# Nearest to been: levellers, forgets, debate, suggested, gabba, deirdre, catastrophe, upgrade,
# Nearest to about: kimmel, milestones, miracleman, detects, hauling, amazon, monthly, nika,
# Nearest to by: paradoxically, gruyter, oppositional, of, merthyr, cour, anakin, iala,
# Nearest to that: uncertainties, indiscernibles, inexplicably, vaccination, environment, raincoat, attributes, clarify,
# Nearest to such: sequential, targeted, theoretical, radiology, biochemical, ebooks, yong, graduation,
# Nearest to or: insertion, instance, lalr, obligation, dots, marginal, bjarne, upside,
# Nearest to to: maintains, vasquez, spoiler, haircut, outlandish, the, namely, diversion,
# Nearest to the: of, in, and, sfg, kolbin, famine, typify, with,
# Nearest to hit: performances, picks, babe, leading, angry, roster, holly, teammates,
# Nearest to pressure: outdoors, everest, joukahainen, yassin, erythrocytes, oscars, aromas, urge,
# Nearest to experience: encyclopedists, sobib, newspaperman, mental, phenomenally, unconscious, melded, twickenham,
# Nearest to stage: dietmar, occurred, mileage, silberman, mediocrity, forefinger, tangle, revulsion,
# Nearest to issue: zavos, ramesh, roamed, revisionist, intuitions, ieoh, publication, preemptive,
# Nearest to placed: waist, autonomic, going, coincide, glaciated, happens, eurozone, fleurs,
# Nearest to test: developer, flintoff, relented, stenosis, urgent, revoluci, lesbia, oswego,
# Nearest to mainly: spanned, jamil, abbasids, resulted, consulate, polonia, kine, amputees,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0833 0.0389 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0635 0.0379 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.1014 0.0374 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0503 0.0376 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0617 0.0378 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0265 0.0371 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.0929 0.0378 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.1047 0.0372 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1135 0.0372 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0534 0.0373 sec/batch
# Nearest to been: levellers, forgets, gabba, deirdre, suggested, debate, catastrophe, looking,
# Nearest to about: milestones, detects, amazon, hauling, monthly, kimmel, miracleman, sea,
# Nearest to by: paradoxically, oppositional, of, gruyter, flashlight, merthyr, anakin, longer,
# Nearest to that: uncertainties, indiscernibles, inexplicably, environment, raincoat, vaccination, rabies, duplicated,
# Nearest to such: sequential, targeted, radiology, overturning, biochemical, yong, theoretical, graduation,
# Nearest to or: insertion, instance, lalr, dots, obligation, restrict, upside, transmembrane,
# Nearest to to: spoiler, maintains, thoroughbred, diversion, disallowing, namely, haircut, the,
# Nearest to the: of, in, and, with, kolbin, sfg, famine, pawns,
# Nearest to hit: performances, babe, picks, holly, hits, leading, cubs, roster,
# Nearest to pressure: outdoors, joukahainen, erythrocytes, everest, aromas, yassin, urge, discharges,
# Nearest to experience: encyclopedists, sobib, newspaperman, phenomenally, unconscious, melded, mental, twickenham,
# Nearest to stage: dietmar, mileage, occurred, silberman, napalm, trained, forefinger, mediocrity,
# Nearest to issue: zavos, ramesh, roamed, intuitions, preemptive, retouched, revisionist, valuation,
# Nearest to placed: autonomic, waist, coincide, going, glaciated, eurozone, toed, happens,
# Nearest to test: developer, flintoff, relented, revoluci, stenosis, urgent, lesbia, iname,
# Nearest to mainly: jamil, spanned, abbasids, consulate, kine, polonia, resulted, responsive,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0233 0.0384 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0525 0.0378 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 3.9995 0.0373 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0473 0.0373 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0886 0.0375 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0637 0.0373 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0752 0.0377 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.1148 0.0377 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0521 0.0377 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0477 0.0378 sec/batch
# Nearest to been: levellers, forgets, debate, deirdre, suggested, gabba, palmerston, poetica,
# Nearest to about: miracleman, kimmel, monthly, detects, milestones, amazon, gatekeeper, nika,
# Nearest to by: paradoxically, oppositional, of, anakin, gruyter, xvi, bagley, iala,
# Nearest to that: indiscernibles, uncertainties, inexplicably, vaccination, environment, it, intelligencer, duplicated,
# Nearest to such: sequential, targeted, biochemical, theoretical, overturning, radiology, cpt, ebooks,
# Nearest to or: instance, insertion, lalr, dots, transmembrane, obligation, restrict, predicates,
# Nearest to to: namely, regardless, spoiler, outlandish, disallowing, referees, deemphasized, seeks,
# Nearest to the: of, in, and, kolbin, exerts, diatoms, sfg, votes,
# Nearest to hit: performances, babe, picks, hits, leading, cue, cubs, englehart,
# Nearest to pressure: outdoors, joukahainen, erythrocytes, oscars, aromas, yassin, discharges, secretes,
# Nearest to experience: encyclopedists, sobib, phenomenally, unconscious, newspaperman, twickenham, mental, surveyed,
# Nearest to stage: dietmar, mileage, silberman, occurred, mediocrity, napalm, flutist, mauryan,
# Nearest to issue: zavos, ramesh, roamed, publication, revisionist, intuitions, ieoh, retouched,
# Nearest to placed: waist, autonomic, coincide, going, glaciated, happens, toed, canto,
# Nearest to test: developer, flintoff, relented, stenosis, urgent, revoluci, lesbia, iname,
# Nearest to mainly: spanned, jamil, abbasids, polonia, kine, consulate, rite, steadily,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0556 0.0389 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0965 0.0380 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0785 0.0379 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0645 0.0376 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0551 0.0377 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0605 0.0374 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0506 0.0372 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0617 0.0374 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0756 0.0373 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0659 0.0376 sec/batch
# Nearest to been: forgets, levellers, gabba, debate, suggested, palmerston, deirdre, upgrade,
# Nearest to about: kimmel, miracleman, milestones, detects, amazon, tibeto, gatekeeper, hauling,
# Nearest to by: oppositional, of, paradoxically, sudan, anakin, cour, iala, gruyter,
# Nearest to that: indiscernibles, uncertainties, inexplicably, vii, intelligencer, vaccination, bjorn, raincoat,
# Nearest to such: sequential, targeted, overturning, theoretical, graduation, functional, biochemical, debased,
# Nearest to or: insertion, instance, dots, lalr, noodle, restrict, obligation, upside,
# Nearest to to: the, namely, spoiler, vasquez, outlandish, tsar, aegon, chavez,
# Nearest to the: of, in, and, kolbin, a, coalitions, with, typify,
# Nearest to hit: performances, hits, babe, picks, englehart, holly, leading, cue,
# Nearest to pressure: yassin, oscars, joukahainen, outdoors, erythrocytes, nadezhda, sectional, urge,
# Nearest to experience: encyclopedists, sobib, phenomenally, surveyed, newspaperman, unconscious, twickenham, melded,
# Nearest to stage: dietmar, mileage, occurred, silberman, mediocrity, mauryan, napalm, flutist,
# Nearest to issue: zavos, ramesh, roamed, revisionist, intuitions, surah, publication, retouched,
# Nearest to placed: going, canto, coincide, autonomic, jubal, waist, toed, eurozone,
# Nearest to test: developer, flintoff, relented, stenosis, revoluci, urgent, collage, lesbia,
# Nearest to mainly: spanned, jamil, consulate, abbasids, rite, polonia, kine, resulted,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0550 0.0389 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 3.9840 0.0379 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0316 0.0376 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0498 0.0374 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0826 0.0372 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1103 0.0371 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1465 0.0372 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0239 0.0374 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0437 0.0372 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0619 0.0370 sec/batch
# Nearest to been: debate, forgets, palmerston, gabba, levellers, suggested, upgrade, deirdre,
# Nearest to about: kimmel, miracleman, milestones, monthly, amazon, nika, discussions, xenobiology,
# Nearest to by: oppositional, paradoxically, of, gruyter, iala, sudan, anakin, longer,
# Nearest to that: indiscernibles, uncertainties, inexplicably, duplicated, reported, intelligencer, raincoat, vaccination,
# Nearest to such: sequential, targeted, functional, overturning, radiology, theoretical, bea, yong,
# Nearest to or: instance, insertion, lalr, dots, restrict, marginal, predicates, seasoning,
# Nearest to to: vasquez, subdivision, spoiler, chavez, namely, salmi, there, loathed,
# Nearest to the: of, in, and, kolbin, coalitions, with, votes, exerts,
# Nearest to hit: performances, babe, hits, angry, leading, holly, englehart, cue,
# Nearest to pressure: yassin, oscars, joukahainen, outdoors, erythrocytes, sectional, given, urge,
# Nearest to experience: phenomenally, encyclopedists, surveyed, sobib, newspaperman, melded, unconscious, cancelled,
# Nearest to stage: dietmar, mileage, occurred, danny, silberman, mediocrity, revulsion, performers,
# Nearest to issue: zavos, ramesh, roamed, revisionist, publication, preemptive, intuitions, retouched,
# Nearest to placed: coincide, going, autonomic, eurozone, waist, toed, jubal, glaciated,
# Nearest to test: developer, flintoff, stenosis, relented, revoluci, charcot, lesbia, tangents,
# Nearest to mainly: spanned, jamil, polonia, abbasids, kine, resulted, memorizing, responsive,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9688 0.0383 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0031 0.0372 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0282 0.0376 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0190 0.0376 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0767 0.0370 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0235 0.0347 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 4.0119 0.0373 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9886 0.0371 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0050 0.0372 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9705 0.0372 sec/batch
# Nearest to been: gabba, levellers, debate, forgets, palmerston, poetica, looking, deirdre,
# Nearest to about: kimmel, amazon, monthly, milestones, miracleman, detects, summaries, inline,
# Nearest to by: oppositional, of, paradoxically, gruyter, the, implausible, anakin, merthyr,
# Nearest to that: indiscernibles, it, duplicated, uncertainties, inexplicably, reported, raincoat, bjorn,
# Nearest to such: sequential, targeted, overturning, theoretical, bea, functional, biochemical, graduation,
# Nearest to or: instance, insertion, restrict, transmembrane, spiritually, noodle, lalr, dots,
# Nearest to to: the, namely, there, javelin, outlandish, spoiler, chavez, through,
# Nearest to the: of, in, and, with, kolbin, a, to, by,
# Nearest to hit: performances, babe, hits, englehart, holly, cue, leading, sweep,
# Nearest to pressure: oscars, joukahainen, yassin, outdoors, given, erythrocytes, unicast, muonium,
# Nearest to experience: surveyed, encyclopedists, phenomenally, sobib, newspaperman, mental, melded, unconscious,
# Nearest to stage: dietmar, mileage, occurred, tangle, napalm, mauryan, silberman, revulsion,
# Nearest to issue: zavos, ramesh, roamed, publication, revisionist, retouched, intuitions, ieoh,
# Nearest to placed: coincide, waist, going, autonomic, fleurs, happens, toed, peg,
# Nearest to test: developer, flintoff, relented, stenosis, revoluci, lesbia, urgent, brothel,
# Nearest to mainly: spanned, abbasids, jamil, polonia, responsive, resulted, memorizing, confucianism,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 4.0055 0.0383 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9483 0.0374 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.0064 0.0371 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0524 0.0370 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0078 0.0371 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 4.0160 0.0371 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.9145 0.0374 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9815 0.0371 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9194 0.0372 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9665 0.0372 sec/batch
# Nearest to been: gabba, forgets, palmerston, debate, suggested, levellers, poetica, looking,
# Nearest to about: kimmel, monthly, amazon, milestones, miracleman, detects, bolo, tibeto,
# Nearest to by: of, paradoxically, oppositional, the, zero, iala, implausible, repertoire,
# Nearest to that: indiscernibles, it, duplicated, raincoat, hydrodynamic, inexplicably, reported, because,
# Nearest to such: targeted, sequential, overturning, radiology, graduation, biochemical, functional, yong,
# Nearest to or: insertion, instance, seasoning, transmembrane, dots, noodle, restrict, is,
# Nearest to to: the, purists, spoiler, jarring, portfolios, through, crossbar, subdivision,
# Nearest to the: of, in, and, a, with, by, to, as,
# Nearest to hit: babe, performances, hits, cue, leading, midpoint, cubs, angry,
# Nearest to pressure: oscars, joukahainen, yassin, outdoors, erythrocytes, given, urge, sectional,
# Nearest to experience: phenomenally, surveyed, encyclopedists, sobib, melded, unconscious, mental, newspaperman,
# Nearest to stage: dietmar, mileage, occurred, launchers, mauryan, napalm, tangle, survivability,
# Nearest to issue: zavos, ramesh, roamed, publication, revisionist, retouched, intuitions, ieoh,
# Nearest to placed: coincide, waist, going, autonomic, eurozone, toed, fleurs, riigikogu,
# Nearest to test: flintoff, developer, relented, stenosis, brothel, lesbia, revoluci, caretaker,
# Nearest to mainly: spanned, abbasids, jamil, polonia, responsive, confucianism, memorizing, resulted,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 3.9996 0.0382 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 3.9918 0.0371 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9585 0.0371 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 3.9826 0.0373 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0265 0.0372 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9721 0.0374 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 4.0118 0.0372 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 4.0064 0.0372 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.9856 0.0376 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 4.0252 0.0371 sec/batch
# Nearest to been: gabba, forgets, debate, palmerston, looking, levellers, suggested, popularize,
# Nearest to about: monthly, kimmel, miracleman, milestones, amazon, summaries, tibeto, discussions,
# Nearest to by: oppositional, of, paradoxically, the, anakin, nationalization, koestler, iala,
# Nearest to that: indiscernibles, it, duplicated, intelligencer, reported, forgo, not, raincoat,
# Nearest to such: targeted, sequential, overturning, functional, graduation, theoretical, radiology, biochemical,
# Nearest to or: instance, insertion, restrict, seasoning, lalr, dots, transmembrane, obj,
# Nearest to to: the, salmi, there, regardless, through, least, vasquez, crossbar,
# Nearest to the: of, in, and, with, a, to, kolbin, by,
# Nearest to hit: performances, cue, babe, hits, leading, midpoint, holly, englehart,
# Nearest to pressure: oscars, yassin, given, joukahainen, erythrocytes, sectional, outdoors, constituting,
# Nearest to experience: phenomenally, surveyed, sobib, encyclopedists, unconscious, mental, twickenham, newspaperman,
# Nearest to stage: mileage, dietmar, occurred, napalm, mauryan, tangle, early, mediocrity,
# Nearest to issue: zavos, ramesh, roamed, revisionist, publication, spokesman, preemptive, retouched,
# Nearest to placed: going, coincide, toed, waist, plucking, eurozone, autonomic, peg,
# Nearest to test: developer, flintoff, stenosis, relented, revoluci, caretaker, lesbia, constraint,
# Nearest to mainly: spanned, abbasids, polonia, jamil, tylor, resulted, responsive, confucianism,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 3.9965 0.0384 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9588 0.0372 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 4.0053 0.0372 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 3.9941 0.0376 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 3.9993 0.0376 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 4.0159 0.0374 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9536 0.0373 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9289 0.0371 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9592 0.0372 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 3.9966 0.0372 sec/batch
# Nearest to been: debate, palmerston, gabba, forgets, levellers, upgrade, suggested, looking,
# Nearest to about: kimmel, monthly, tibeto, milestones, amazon, miracleman, discussions, briefing,
# Nearest to by: of, oppositional, the, nationalization, paradoxically, zero, implausible, anakin,
# Nearest to that: indiscernibles, it, those, reported, combatant, duplicated, soundness, intelligencer,
# Nearest to such: targeted, sequential, overturning, radiology, biochemical, stacks, functional, mulder,
# Nearest to or: insertion, instance, is, restrict, dots, transmembrane, seasoning, obligation,
# ...
# Epoch 9/10 Iteration: 38400 Avg. Training loss: 3.7836 0.0373 sec/batch
# Epoch 9/10 Iteration: 38500 Avg. Training loss: 3.8294 0.0376 sec/batch
# Epoch 9/10 Iteration: 38600 Avg. Training loss: 3.8586 0.0376 sec/batch
# Epoch 9/10 Iteration: 38700 Avg. Training loss: 3.8533 0.0376 sec/batch
# Epoch 9/10 Iteration: 38800 Avg. Training loss: 3.8237 0.0372 sec/batch
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 3.8652 0.0373 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 3.8888 0.0373 sec/batch
# Nearest to been: has, had, that, gabba, was, it, suggested, looking,
# Nearest to about: three, chukchi, zero, monthly, summaries, kimmel, intervening, bolo,
# Nearest to by: of, the, and, a, as, to, in, for,
# Nearest to that: not, it, because, be, been, have, had, though,
# Nearest to such: targeted, as, mediators, used, predestination, readable, holomorphic, stacks,
# Nearest to or: is, instance, either, as, are, seasoning, and, also,
# Nearest to to: the, and, be, of, in, while, by, as,
# Nearest to the: of, in, and, a, by, as, to, with,
# Nearest to hit: hits, mangaverse, balk, cue, stepdaughter, babe, haq, hina,
# Nearest to pressure: given, oscars, seleucids, baroness, compressor, aerodynamically, tightened, detonator,
# Nearest to experience: phenomenally, twickenham, mental, photographer, enormously, examination, encyclopedists, immunities,
# Nearest to stage: mileage, dietmar, occurred, ended, mauryan, hollywood, skydiver, chromosomal,
# Nearest to issue: zavos, publication, liabilities, detest, trimmed, stan, approached, roamed,
# Nearest to placed: beak, eurozone, observatories, keypad, toed, coincide, inserted, attributes,
# Nearest to test: tests, flintoff, testing, caretaker, relented, stenosis, tuol, developer,
# Nearest to mainly: spanned, equity, few, polonia, sala, iroquois, euphoric, saunders,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8532 0.0383 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8434 0.0374 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8666 0.0371 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8419 0.0372 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8649 0.0371 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8571 0.0376 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8590 0.0375 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8286 0.0373 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8808 0.0373 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8697 0.0370 sec/batch
# Nearest to been: had, has, that, was, gabba, suggested, it, indicate,
# Nearest to about: three, it, zero, externalism, in, milk, bolo, kimmel,
# Nearest to by: of, the, and, a, as, to, in, one,
# Nearest to that: not, it, had, have, been, because, though, indiscernibles,
# Nearest to such: targeted, as, predestination, vast, mediators, stacks, mulder, emesa,
# Nearest to or: is, are, either, instance, as, seasoning, and, giuliani,
# Nearest to to: the, and, of, in, with, as, by, however,
# Nearest to the: of, in, and, a, by, to, as, with,
# Nearest to hit: hits, mangaverse, cue, balk, stepdaughter, babe, hina, sensation,
# Nearest to pressure: oscars, given, seleucids, baroness, yassin, detonator, aerodynamically, compressor,
# Nearest to experience: phenomenally, twickenham, mental, enormously, immunities, encyclopedists, taxing, photographer,
# Nearest to stage: mileage, dietmar, occurred, ended, mauryan, skydiver, revivals, hollywood,
# Nearest to issue: zavos, publication, liabilities, supermajority, roamed, detest, trimmed, stan,
# Nearest to placed: eurozone, beak, toed, observatories, keypad, coincide, commissars, attributes,
# Nearest to test: tests, flintoff, testing, caretaker, relented, stenosis, tuol, lesbia,
# Nearest to mainly: spanned, equity, few, sura, tylor, saunders, iroquois, euphoric,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8664 0.0386 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8686 0.0371 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8254 0.0372 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8081 0.0372 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.8825 0.0376 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8336 0.0376 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9812 0.0372 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.9010 0.0371 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.9052 0.0372 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.8345 0.0374 sec/batch
# Nearest to been: has, had, that, was, it, gabba, suggested, its,
# Nearest to about: three, it, in, externalism, zero, bolo, chukchi, have,
# Nearest to by: of, the, and, a, as, to, in, s,
# Nearest to that: not, it, had, have, been, because, be, claim,
# Nearest to such: as, targeted, and, concurrency, many, emesa, polonia, stacks,
# Nearest to or: is, either, are, as, instance, seasoning, used, combination,
# Nearest to to: the, and, of, as, with, in, by, while,
# Nearest to the: of, in, and, a, by, as, to, an,
# Nearest to hit: hits, balk, cue, mangaverse, stepdaughter, babe, sensation, leaguers,
# Nearest to pressure: oscars, given, seleucids, baroness, yassin, aerodynamically, compressor, deteriorate,
# Nearest to experience: phenomenally, twickenham, mental, immunities, encyclopedists, enormously, taxing, photographer,
# Nearest to stage: mileage, dietmar, occurred, ended, hollywood, performance, skydiver, revivals,
# Nearest to issue: zavos, publication, liabilities, supermajority, detest, trimmed, approached, stan,
# Nearest to placed: eurozone, coincide, toed, observatories, keypad, going, commissars, beak,
# Nearest to test: tests, flintoff, testing, caretaker, stenosis, relented, tuol, lenstra,
# Nearest to mainly: spanned, few, equity, iroquois, euphoric, tylor, adipose, polonia,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.7882 0.0381 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8486 0.0376 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.7848 0.0372 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8736 0.0373 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8332 0.0372 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8836 0.0373 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.8770 0.0219 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8198 0.0373 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8484 0.0372 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8366 0.0372 sec/batch
# Nearest to been: had, that, has, was, it, gabba, suggested, the,
# Nearest to about: bolo, it, chukchi, three, have, in, zero, intervening,
# Nearest to by: of, the, a, and, to, in, as, was,
# Nearest to that: not, it, because, been, have, be, had, to,
# Nearest to such: as, targeted, emesa, and, many, acculturation, mediators, liberaci,
# Nearest to or: as, is, either, instance, are, and, used, combination,
# Nearest to to: the, of, and, in, by, as, with, be,
# Nearest to the: of, in, and, a, by, to, as, from,
# Nearest to hit: hits, balk, cue, mangaverse, stepdaughter, babe, leaguers, sensation,
# Nearest to pressure: oscars, baroness, given, seleucids, compressor, yassin, everest, pas,
# Nearest to experience: twickenham, phenomenally, mental, enormously, encyclopedists, taxing, immunities, photographer,
# Nearest to stage: mileage, occurred, dietmar, skydiver, ended, erythrocytes, chromosomal, revivals,
# Nearest to issue: publication, zavos, supermajority, liabilities, trimmed, stan, detest, approached,
# Nearest to placed: observatories, eurozone, coincide, keypad, toed, attributes, inserted, beak,
# Nearest to test: tests, flintoff, testing, caretaker, relented, stenosis, lenstra, developer,
# Nearest to mainly: spanned, equity, few, polonia, iroquois, gradually, tylor, yoshitaka,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.8166 0.0385 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.8284 0.0373 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.8421 0.0375 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.7999 0.0374 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8301 0.0374 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8435 0.0373 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8925 0.0375 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7437 0.0373 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.8301 0.0371 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.8031 0.0372 sec/batch
# Nearest to been: had, has, was, it, that, gabba, suggested, indicate,
# Nearest to about: it, three, zero, chukchi, ft, bolo, milk, in,
# Nearest to by: of, the, a, and, as, to, in, for,
# Nearest to that: not, it, have, be, because, this, a, the,
# Nearest to such: and, as, targeted, used, many, emesa, mediators, polonia,
# Nearest to or: is, as, are, and, either, used, instance, the,
# Nearest to to: the, and, of, is, in, as, by, however,
# Nearest to the: of, in, and, a, as, by, to, is,
# Nearest to hit: hits, balk, cue, stepdaughter, mangaverse, babe, batted, hina,
# Nearest to pressure: given, baroness, oscars, seleucids, yassin, detonator, deteriorate, compressor,
# Nearest to experience: twickenham, phenomenally, enormously, mental, immunities, encyclopedists, photographer, examination,
# Nearest to stage: mileage, skydiver, dietmar, launchers, early, ended, occurred, mauryan,
# Nearest to issue: publication, trimmed, zavos, liabilities, supermajority, stan, approached, roamed,
# Nearest to placed: eurozone, observatories, keypad, coincide, commissars, toed, beak, attributes,
# Nearest to test: tests, flintoff, testing, relented, caretaker, lenstra, stenosis, awaited,
# Nearest to mainly: few, spanned, equity, iroquois, polonia, euphoric, killian, tylor,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7662 0.0381 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8469 0.0372 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8329 0.0371 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.8457 0.0372 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.8213 0.0371 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.8988 0.0371 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8502 0.0372 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.8028 0.0371 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8205 0.0371 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8369 0.0372 sec/batch
# Nearest to been: had, has, was, that, it, gabba, suggested, dated,
# Nearest to about: three, it, bolo, chukchi, have, milk, summaries, intervening,
# Nearest to by: of, the, a, and, to, as, for, s,
# Nearest to that: not, it, have, be, because, had, been, this,
# Nearest to such: and, targeted, as, mediators, kerensky, emesa, predestination, earlier,
# Nearest to or: is, as, either, are, instance, of, the, also,
# Nearest to to: the, and, of, be, in, is, while, by,
# Nearest to the: of, in, a, and, to, as, by, with,
# Nearest to hit: hits, cue, balk, mangaverse, stepdaughter, sensation, babe, hina,
# Nearest to pressure: given, baroness, oscars, seleucids, yassin, detonator, compressor, deteriorate,
# Nearest to experience: phenomenally, twickenham, mental, photographer, examination, encyclopedists, taxing, surveyed,
# Nearest to stage: mileage, ended, early, revivals, occurred, dietmar, emmy, hollywood,
# Nearest to issue: publication, zavos, trimmed, stan, supermajority, liabilities, approached, entrepreneurial,
# Nearest to placed: keypad, eurozone, inserted, coincide, observatories, toed, beak, commissars,
# Nearest to test: tests, flintoff, testing, relented, caretaker, lenstra, awaited, stenosis,
# Nearest to mainly: few, spanned, equity, polonia, iroquois, killian, tylor, yoshitaka,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8656 0.0382 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8567 0.0371 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.8246 0.0372 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8170 0.0372 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8760 0.0372 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8549 0.0373 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.7916 0.0373 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8638 0.0374 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.8015 0.0371 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.8340 0.0372 sec/batch
# Nearest to been: has, had, was, that, it, gabba, its, suggested,
# Nearest to about: it, three, in, have, chukchi, intervening, externalism, zero,
# Nearest to by: of, the, a, and, to, s, for, as,
# Nearest to that: not, it, have, been, this, because, had, be,
# Nearest to such: and, as, targeted, many, most, used, more, mediators,
# Nearest to or: is, as, are, either, used, instance, also, of,
# Nearest to to: the, of, and, in, by, be, as, with,
# Nearest to the: of, and, in, a, by, to, as, with,
# Nearest to hit: hits, balk, cue, stepdaughter, mangaverse, babe, leaguers, batted,
# Nearest to pressure: seleucids, given, baroness, oscars, yassin, everest, deteriorate, detonator,
# Nearest to experience: phenomenally, mental, twickenham, examination, enormously, immunities, photographer, encyclopedists,
# Nearest to stage: mileage, ended, mauryan, dietmar, emmy, lilo, occurred, theatre,
# Nearest to issue: publication, zavos, supermajority, trimmed, stan, liabilities, approached, manuscript,
# Nearest to placed: eurozone, keypad, coincide, observatories, toed, beak, inserted, commissars,
# Nearest to test: tests, testing, flintoff, relented, caretaker, stenosis, lesbia, lenstra,
# Nearest to mainly: few, equity, spanned, euphoric, tylor, polonia, iroquois, gradually,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8621 0.0383 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.8083 0.0374 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.9300 0.0372 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.9127 0.0372 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.8602 0.0371 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8565 0.0373 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7740 0.0371 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8669 0.0369 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7419 0.0375 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8732 0.0376 sec/batch
# Nearest to been: has, had, was, it, that, suggested, gabba, well,
# Nearest to about: it, three, chukchi, in, at, bolo, have, m,
# Nearest to by: of, the, a, and, to, as, on, s,
# Nearest to that: not, it, have, because, this, be, the, been,
# Nearest to such: and, as, targeted, many, include, addition, used, most,
# Nearest to or: is, are, either, as, used, and, combination, also,
# Nearest to to: the, and, of, as, with, in, be, by,
# Nearest to the: of, and, a, in, by, to, with, as,
# Nearest to hit: hits, balk, mangaverse, stepdaughter, cue, sensation, leaguers, babe,
# Nearest to pressure: given, seleucids, baroness, oscars, yassin, detonator, everest, retrospect,
# Nearest to experience: mental, phenomenally, taxing, photographer, twickenham, immunities, examination, enormously,
# Nearest to stage: mileage, ended, theatre, emmy, revivals, hollywood, lilo, dietmar,
# Nearest to issue: publication, zavos, supermajority, stan, trimmed, liabilities, approached, manuscript,
# Nearest to placed: eurozone, observatories, keypad, coincide, commissars, toed, inserted, attributes,
# Nearest to test: tests, flintoff, testing, caretaker, relented, lenstra, stenosis, awaited,
# Nearest to mainly: few, equity, spanned, gradually, polonia, iroquois, euphoric, more,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8284 0.0383 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8030 0.0372 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
# with train_graph.as_default():
#     saver = tf.train.Saver()

# with tf.Session(graph=train_graph) as sess:
#     saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
#     embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE (t-Distributed Stochastic Neighbor Embedding) to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)

# %%
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[valid_examples, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(len(valid_examples)):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[valid_examples[idx]], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
