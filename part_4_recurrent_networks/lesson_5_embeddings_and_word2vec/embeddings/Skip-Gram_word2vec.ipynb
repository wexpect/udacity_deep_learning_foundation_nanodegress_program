# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %%
type(text)
# Out:
# str

# %%
len(text)
# Out:
# 100000000

# %%
text[:1000]
# Out:
# ' anarchism originated as a term of abuse first used against early working class radicals including the diggers of the english revolution and the sans culottes of the french revolution whilst the term is still used in a pejorative way to describe any act that used violent means to destroy the organization of society it has also been taken up as a positive label by self defined anarchists the word anarchism is derived from the greek without archons ruler chief king anarchism as a political philosophy is the belief that rulers are unnecessary and should be abolished although there are differing interpretations of what this means anarchism also refers to related social movements that advocate the elimination of authoritarian institutions particularly the state the word anarchy as most anarchists use it does not imply chaos nihilism or anomie but rather a harmonious anti authoritarian society in place of what are regarded as authoritarian political structures and coercive economic instituti'

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %%
print(words[:200])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst', 'the', 'term', 'is', 'still', 'used', 'in', 'a', 'pejorative', 'way', 'to', 'describe', 'any', 'act', 'that', 'used', 'violent', 'means', 'to', 'destroy', 'the', 'organization', 'of', 'society', 'it', 'has', 'also', 'been', 'taken', 'up', 'as', 'a', 'positive', 'label', 'by', 'self', 'defined', 'anarchists', 'the', 'word', 'anarchism', 'is', 'derived', 'from', 'the', 'greek', 'without', 'archons', 'ruler', 'chief', 'king', 'anarchism', 'as', 'a', 'political', 'philosophy', 'is', 'the', 'belief', 'that', 'rulers', 'are', 'unnecessary', 'and', 'should', 'be', 'abolished', 'although', 'there', 'are', 'differing', 'interpretations', 'of', 'what', 'this', 'means', 'anarchism', 'also', 'refers', 'to', 'related', 'social', 'movements', 'that', 'advocate', 'the', 'elimination', 'of', 'authoritarian', 'institutions', 'particularly', 'the', 'state', 'the', 'word', 'anarchy', 'as', 'most', 'anarchists', 'use', 'it', 'does', 'not', 'imply', 'chaos', 'nihilism', 'or', 'anomie', 'but', 'rather', 'a', 'harmonious', 'anti', 'authoritarian', 'society', 'in', 'place', 'of', 'what', 'are', 'regarded', 'as', 'authoritarian', 'political', 'structures', 'and', 'coercive', 'economic', 'institutions', 'anarchists', 'advocate', 'social', 'relations', 'based', 'upon', 'voluntary', 'association', 'of', 'autonomous', 'individuals', 'mutual', 'aid', 'and', 'self', 'governance', 'while', 'anarchism', 'is', 'most', 'easily', 'defined', 'by', 'what', 'it', 'is', 'against', 'anarchists', 'also', 'offer', 'positive', 'visions', 'of', 'what', 'they', 'believe', 'to', 'be', 'a', 'truly', 'free', 'society']

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %%
[int_to_vocab[i] for i in range(10)]
# Out:
# ['the', 'of', 'and', 'one', 'in', 'a', 'to', 'zero', 'nine', 'two']

# %%
vocab_to_int['the'], vocab_to_int['person']
# Out:
# (0, 397)

# %%
int_words[:15]
# Out:
# [5233, 3081, 11, 5, 194, 1, 3134, 45, 58, 155, 127, 741, 476, 10636, 133]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
## Your code here

import math

def get_discard_prob(freq, threshold):
    return 1 - math.sqrt(threshold / freq)

# %%
import matplotlib.pyplot as plt
plt.plot(
    [i * 0.01 for i in range(1, 100, 1)], 
    [get_discard_prob(i * 0.01, 0.2) for i in range(1, 100, 1)]
)
plt.show()

# %%
from collections import Counter

total_words_count = len(int_words)
int_words_count = Counter(int_words)

# %%
total_words_count
# Out:
# 16680599

# %%
int_words_count[5233]
# Out:
# 303

# %%
int_words_count[5233]  / total_words_count
# Out:
# 1.8164815304294527e-05

# %%
10e-5
# Out:
# 0.0001

# %%
import random

min_discard_prob = 1e-5  # 10e-5

train_words = []
for int_word in int_words:
    count = int_words_count[int_word] 
    freq = count / total_words_count
    discard_prob = get_discard_prob(freq, min_discard_prob)
#     print('int_word=', int_word, ', ', int_to_vocab[int_word], ', freq=', freq, ', discard_prob=', discard_prob)
    
    if random.random() <= discard_prob:
        # discard word
#         print('drop int_word')
        pass
    else:
        # keep word
        train_words.append(int_word)

# %%
total_words_count, len(train_words)
# Out:
# (16680599, 4626850)

# %%
int_words[:10]
# Out:
# [5233, 3081, 11, 5, 194, 1, 3134, 45, 58, 155]

# %%
train_words[:10] # The final subsampled word list
# Out:
# [5233, 3134, 155, 741, 10636, 27780, 854, 15084, 61229, 3582]

# %%
int_to_vocab[3080], int_to_vocab[11], int_to_vocab[5], int_to_vocab[194], int_to_vocab[1], int_to_vocab[3133], int_to_vocab[45], int_to_vocab[58]
# Out:
# ('matrix', 'as', 'a', 'term', 'of', 'presidency', 'first', 'used')

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
[0, 1, 2, 3][4:8]
# Out:
# []

# %%
random.randint(1, 5)
# Out:
# 3

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''    
    # Your code here    
    r = random.randint(1, window_size)   
    
    left_idx = idx - r
    if left_idx < 0:
        left_idx = 0
        
    target = words[left_idx: idx] + words[idx + 1 : idx + 1 + r]        
    return list(set(target))

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words) // batch_size
    
    # only full batches
    words = words[: n_batches * batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx: idx + batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x] * len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None])
    labels = tf.placeholder(tf.int32, [None, 1])

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200 # Number of embedding features 

with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform([n_vocab, n_embedding], minval=-1, maxval=1))  # create embedding weight matrix here
    embed = tf.nn.embedding_lookup(embedding, inputs)  # use tf.nn.embedding_lookup to get the hidden layer output

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    # NOTE: pay attention, the dimension here is transposed
    softmax_w = tf.Variable(tf.truncated_normal([n_vocab, n_embedding], stddev=0.1)) # create softmax weight matrix here
    softmax_b = tf.Variable(tf.zeros(n_vocab))  # create softmax biases here
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(
        softmax_w,
        softmax_b,
        labels,
        embed,
        n_sampled,
        n_vocab,
    )
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
random.sample(range(10), 4)
# Out:
# [6, 8, 0, 7]

# %%
# import random

# ## From Thushan Ganegedara's implementation
# valid_size = 16 # Random set of words to evaluate similarity on.
# valid_window = 100
# # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
# valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
# valid_examples = np.append(
#     valid_examples, 
#     random.sample(range(1000,1000+valid_window), valid_size//2)
# )

valid_examples = [
    vocab_to_int[i] for i in [
        'person', 'people', 'human', 'boy', 'girl', 'man', 'woman', 'baby', 'father', 'mother', 
        'king', 'queen',  'prince', 'princess', 'general', 'soldier',
        'dog', 'pig', 'cat', 'mouse', 'fish', 'bird', 'eagle', 'pigeon',
        'tree', 'flower', 'grass', 'apple', 'orange', 'grape',
        'red', 'green', 'yellow', 'blue', 'dark',
        'sun', 'earth', 'mars', 'moon', 'universe',
        'water', 'fire', 'stone',
        'run', 'walk', 'crawl', 'jump', 'jog',
        'food', 'meal', 'breakfast', 'lunch', 'dinner', 'meat', 'rice', 'vegetable',
        'love', 'hate', 'kiss', 'kill', 'war', 'peace',
        'machine',
        'country', 'china', 'america', 'korean', 'russia', 'german', 'spain', 'brazil',
    ]
]
valid_size = len(valid_examples)

valid_examples
# Out:
# [397,
#  82,
#  225,
#  1496,
#  2588,
#  242,
#  1011,
#  3435,
#  408,
#  729,
#  186,
#  902,
#  1060,
#  3421,
#  152,
#  3087,
#  1900,
#  9103,
#  2599,
#  2794,
#  1524,
#  2974,
#  5991,
#  15571,
#  1237,
#  5526,
#  6014,
#  1218,
#  2932,
#  15762,
#  411,
#  828,
#  2459,
#  758,
#  1301,
#  903,
#  329,
#  2374,
#  949,
#  1008,
#  287,
#  670,
#  1481,
#  533,
#  3194,
#  27694,
#  4515,
#  35313,
#  641,
#  7162,
#  11867,
#  14818,
#  9393,
#  2910,
#  2970,
#  8209,
#  610,
#  5543,
#  7977,
#  2249,
#  83,
#  791,
#  798,
#  185,
#  485,
#  356,
#  2327,
#  748,
#  171,
#  804,
#  1879]

# %%
with train_graph.as_default():
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints
# Out:
# mkdir: cannot create directory ‘checkpoints’: File exists

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 6
batch_size = 1000
window_size = 10

# %%
batches_per_epoch = len(train_words) / batch_size
batches_per_epoch
# Out:
# 4626.85

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
                
            if iteration % 2000 == 0:  # if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
            
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/6 Iteration: 100 Avg. Training loss: 5.6563 0.0827 sec/batch
# Epoch 1/6 Iteration: 200 Avg. Training loss: 5.6241 0.0816 sec/batch
# Epoch 1/6 Iteration: 300 Avg. Training loss: 5.5193 0.0816 sec/batch
# Epoch 1/6 Iteration: 400 Avg. Training loss: 5.5794 0.0818 sec/batch
# Epoch 1/6 Iteration: 500 Avg. Training loss: 5.5171 0.0827 sec/batch
# Epoch 1/6 Iteration: 600 Avg. Training loss: 5.5221 0.0811 sec/batch
# Epoch 1/6 Iteration: 700 Avg. Training loss: 5.5741 0.0802 sec/batch
# Epoch 1/6 Iteration: 800 Avg. Training loss: 5.5380 0.0809 sec/batch
# Epoch 1/6 Iteration: 900 Avg. Training loss: 5.4334 0.0827 sec/batch
# Epoch 1/6 Iteration: 1000 Avg. Training loss: 5.4438 0.0849 sec/batch
# Epoch 1/6 Iteration: 1100 Avg. Training loss: 5.4715 0.0846 sec/batch
# Epoch 1/6 Iteration: 1200 Avg. Training loss: 5.3579 0.0855 sec/batch
# Epoch 1/6 Iteration: 1300 Avg. Training loss: 5.3397 0.0863 sec/batch
# Epoch 1/6 Iteration: 1400 Avg. Training loss: 5.2130 0.0869 sec/batch
# Epoch 1/6 Iteration: 1500 Avg. Training loss: 5.1748 0.0869 sec/batch
# Epoch 1/6 Iteration: 1600 Avg. Training loss: 5.1207 0.0873 sec/batch
# Epoch 1/6 Iteration: 1700 Avg. Training loss: 5.0795 0.0875 sec/batch
# Epoch 1/6 Iteration: 1800 Avg. Training loss: 5.0584 0.0876 sec/batch
# Epoch 1/6 Iteration: 1900 Avg. Training loss: 4.9883 0.0877 sec/batch
# Epoch 1/6 Iteration: 2000 Avg. Training loss: 4.9898 0.0882 sec/batch
# Nearest to person: stanley, believed, musicals, commentaries, spend, newton, examiners, environment,
# Nearest to people: blend, transaction, replaces, remove, definition, guerrilla, civilization, devonport,
# Nearest to human: supra, guerrilla, duplicity, audience, antenna, meles, conductors, spent,
# Nearest to boy: develops, ktav, mrna, fdc, balm, goodhue, profiles, strains,
# Nearest to girl: field, hendrik, internazionale, caltech, flux, stirrup, rgermeister, alcide,
# Nearest to man: flesh, outlook, eggs, organists, being, sexy, zealous, deserving,
# Nearest to woman: ready, belisarius, sailboats, goes, putting, ppe, catfish, essential,
# Nearest to baby: emphasising, legitimizing, amigos, assure, subsumes, lysenko, narrower, beren,
# Nearest to father: rhodesia, toxicity, asahi, solely, bn, goiter, shrimp, transformational,
# Nearest to mother: raza, formulas, history, lunisolar, jeroboam, workers, impeached, physically,
# Nearest to king: lamp, plan, van, derivates, evacuated, privateers, washington, overbeck,
# Nearest to queen: golden, nota, hast, weaver, that, ran, drexel, normalcy,
# Nearest to prince: mars, defining, cdc, there, caria, infecting, mileage, real,
# Nearest to princess: spectral, dialogue, dmitri, modifications, vms, ole, felix, wealthier,
# Nearest to general: fireballs, kevorkian, nd, park, ricky, bromide, area, sorceress,
# Nearest to soldier: kb, fasting, villain, composer, indian, neologism, taboo, medallion,
# Nearest to dog: porphyry, circa, likelihood, vivre, guatemalan, perspiration, asian, tyrants,
# Nearest to pig: forsythe, aureus, risen, outputting, severely, flavian, shaded, medina,
# Nearest to cat: gotcha, grape, sociologists, vacancy, academic, softening, kamchatsky, trigrams,
# Nearest to mouse: deterred, others, advertisements, taoists, burghers, smegma, moog, appears,
# Nearest to fish: concocted, throwers, unloaded, unconfirmed, parallel, conti, ryaku, wis,
# Nearest to bird: bedford, citizenship, euphemism, spotted, prehispanic, campaign, document, rak,
# Nearest to eagle: crimes, centre, bicycle, salamis, oversized, generalizations, crowley, olive,
# Nearest to pigeon: enlargement, disciplined, ballot, feuerbach, visibly, numa, categories, hm,
# Nearest to tree: stalled, tennant, dropped, disquieting, billion, lyndanisse, lampooned, stimulation,
# Nearest to flower: stalk, emptying, avengers, can, exarchate, timbre, bearshare, lt,
# Nearest to grass: marvellous, simplifies, pred, cravings, incident, dreamed, avenger, promising,
# Nearest to apple: struma, distancing, try, lakewood, planetoid, risk, geological, borough,
# Nearest to orange: beagle, kwanzas, shamir, adhesion, propped, traore, irrelevent, funneled,
# Nearest to grape: chiles, winkler, cat, kyushu, framers, narratives, hamilton, calvert,
# Nearest to red: elements, player, distorting, motown, pemberton, freed, tunnels, thory,
# Nearest to green: quite, disagree, cidre, mixes, just, huge, alcidamas, mother,
# Nearest to yellow: canonical, mediocre, animator, luftwaffe, translators, battersby, newstead, canaria,
# Nearest to blue: whereby, faiths, closed, dynamics, taiping, dexter, continue, caston,
# Nearest to dark: apparition, goofy, copyright, murdoch, assumes, slept, resting, addis,
# Nearest to sun: void, carbons, magnetosphere, worthwhile, innocuous, varied, xii, ultraman,
# Nearest to earth: competence, bands, fires, intact, brooks, focus, transcend, fermium,
# Nearest to mars: tezuka, rdoba, kylix, prince, innocence, covers, supernaturally, anguish,
# Nearest to moon: maxfield, track, incriminating, inoffensive, sncf, torvalds, nitrogen, subsidized,
# Nearest to universe: ugly, councils, poissy, agreed, mobsters, lifetimes, pulcher, laissez,
# Nearest to water: p, wandering, sepsis, isbn, estimating, funding, drill, maturity,
# Nearest to fire: searchers, autism, sorry, wichita, standard, prisoners, shorts, rudin,
# Nearest to stone: lifelong, washtenaw, pale, goals, fork, spy, misunderstanding, wootz,
# Nearest to run: woke, rvi, thirtieth, plaintiffs, substitutes, est, revealing, alaric,
# Nearest to walk: burgundy, tsar, eucharist, shakespeare, accessories, townships, compiler, earliest,
# Nearest to crawl: northwestern, patriarch, employment, heart, paleontologists, explicitly, beds, lysis,
# Nearest to jump: pleasantville, thigh, javan, spirit, kd, unethical, riding, houllier,
# Nearest to jog: republik, radclyffe, certificate, interviewed, strewn, embouchure, compressive, funchal,
# Nearest to food: body, poetic, joni, honoring, airships, alcs, glaciated, assembly,
# Nearest to meal: v, lurker, semple, sinners, coherent, gorgeous, ram, deregulated,
# Nearest to breakfast: obscure, vbscript, windsor, integrate, uncanonical, drastic, viceroyalty, globe,
# Nearest to lunch: sinuous, environment, demonology, scorecard, rhea, sasha, wheeler, afp,
# Nearest to dinner: dream, thinking, jute, vitamin, kline, abstractly, deny, giri,
# Nearest to meat: convey, ambition, olympic, glasnost, gilman, locomotives, scorer, offside,
# Nearest to rice: illustrates, represents, kilogram, defeat, felicity, d, ranged, purpose,
# Nearest to vegetable: frontend, nasi, financing, rascal, trypomastigotes, vertigo, blackburn, ming,
# Nearest to love: jule, theorem, hornet, dedications, motivation, process, entirely, adopted,
# Nearest to hate: claimed, disciplined, skeptics, awful, accumulates, relative, runequest, holes,
# Nearest to kiss: chaos, immediate, faults, stunted, resume, skyline, oshawa, trilobite,
# Nearest to kill: lusaka, aides, woo, deptford, assigning, as, elmo, forcing,
# Nearest to war: screenname, paleogeography, obsession, slow, dermot, lower, hmso, spring,
# Nearest to peace: lecter, fall, elements, expression, gnu, produced, grip, trampled,
# Nearest to machine: arbitrator, points, than, outflows, nose, leaf, signed, eph,
# Nearest to country: codebreaking, importance, proton, needs, issue, binghamton, eventually, camino,
# Nearest to china: rmb, defeating, number, market, pens, violet, supplies, dilbert,
# Nearest to america: than, washington, holiday, compromised, made, co, antonio, passing,
# Nearest to korean: tampa, alter, wave, corned, oka, dairies, shaping, reactant,
# Nearest to russia: pronouns, produce, murray, dulcimer, dunbartonshire, suiko, narratives, koza,
# Nearest to german: their, amputee, methods, sensor, parnell, education, fallen, wiley,
# Nearest to spain: football, multiplier, eject, workshop, six, lengthening, secretive, stalin,
# Nearest to brazil: militarist, interfered, tans, wilkeson, sentenced, massacred, steinbeck, czechs,
# Epoch 1/6 Iteration: 2100 Avg. Training loss: 4.9219 0.0932 sec/batch
# Epoch 1/6 Iteration: 2200 Avg. Training loss: 4.9036 0.0888 sec/batch
# Epoch 1/6 Iteration: 2300 Avg. Training loss: 4.8758 0.0893 sec/batch
# Epoch 1/6 Iteration: 2400 Avg. Training loss: 4.8892 0.0889 sec/batch
# Epoch 1/6 Iteration: 2500 Avg. Training loss: 4.8220 0.0887 sec/batch
# Epoch 1/6 Iteration: 2600 Avg. Training loss: 4.8176 0.0884 sec/batch
# Epoch 1/6 Iteration: 2700 Avg. Training loss: 4.8039 0.0893 sec/batch
# Epoch 1/6 Iteration: 2800 Avg. Training loss: 4.7949 0.0890 sec/batch
# Epoch 1/6 Iteration: 2900 Avg. Training loss: 4.7544 0.0894 sec/batch
# Epoch 1/6 Iteration: 3000 Avg. Training loss: 4.8094 0.0892 sec/batch
# Epoch 1/6 Iteration: 3100 Avg. Training loss: 4.7708 0.0897 sec/batch
# Epoch 1/6 Iteration: 3200 Avg. Training loss: 4.7351 0.0905 sec/batch
# Epoch 1/6 Iteration: 3300 Avg. Training loss: 4.7288 0.0905 sec/batch
# Epoch 1/6 Iteration: 3400 Avg. Training loss: 4.7026 0.0905 sec/batch
# Epoch 1/6 Iteration: 3500 Avg. Training loss: 4.7424 0.0906 sec/batch
# Epoch 1/6 Iteration: 3600 Avg. Training loss: 4.6572 0.0900 sec/batch
# Epoch 1/6 Iteration: 3700 Avg. Training loss: 4.6826 0.0899 sec/batch
# Epoch 1/6 Iteration: 3800 Avg. Training loss: 4.6982 0.0896 sec/batch
# Epoch 1/6 Iteration: 3900 Avg. Training loss: 4.6917 0.0899 sec/batch
# Epoch 1/6 Iteration: 4000 Avg. Training loss: 4.6956 0.0905 sec/batch
# Nearest to person: stanley, deceased, musicals, believed, atahualpa, me, foster, chaucer,
# Nearest to people: blend, guerrilla, kowalski, devonport, replaces, transaction, remove, licence,
# Nearest to human: supra, guerrilla, duplicity, meles, alimentarius, conductors, decreases, dorians,
# Nearest to boy: develops, ktav, profiles, flop, goodhue, mrna, balm, facilitating,
# Nearest to girl: hendrik, field, internazionale, rgermeister, alcide, champions, maitre, anton,
# Nearest to man: outlook, flesh, eggs, organists, sexy, viacom, surfer, zealous,
# Nearest to woman: belisarius, ready, sailboats, ppe, goes, static, graduates, putting,
# Nearest to baby: legitimizing, emphasising, amigos, assure, interpolations, federer, subsumes, bricks,
# Nearest to father: rhodesia, goiter, bn, asahi, toxicity, methuen, darstellende, shrimp,
# Nearest to mother: raza, impeached, luba, jeroboam, workers, antiquated, physically, kettle,
# Nearest to king: van, lamp, plan, andromache, millennia, derivates, overbeck, unitas,
# Nearest to queen: golden, normalcy, hast, nota, weaver, drexel, ran, erhalte,
# Nearest to prince: defining, roman, mars, cdc, connor, mansfield, negligence, mileage,
# Nearest to princess: ole, dmitri, gp, felix, mug, fifteenth, spectral, modifications,
# Nearest to general: fireballs, buck, park, prot, kevorkian, nter, explorations, interferes,
# Nearest to soldier: composer, kb, indian, villain, medallion, wreckage, outset, uscis,
# Nearest to dog: porphyry, vivre, tyrants, tion, immediacy, variant, circa, kosher,
# Nearest to pig: forsythe, participates, shaded, medina, aureus, outputting, addicts, risen,
# Nearest to cat: gotcha, grape, vacancy, sociologists, softening, upset, romances, invoked,
# Nearest to mouse: deterred, moog, taoists, burghers, others, advertisements, garifuna, smegma,
# Nearest to fish: unconfirmed, concocted, throwers, conti, sustainable, unloaded, wis, abbotsford,
# Nearest to bird: bedford, rak, citizenship, spotted, surveyed, euphemism, boac, prehispanic,
# Nearest to eagle: crimes, centre, salamis, crowley, oversized, suitors, bicycle, generalizations,
# Nearest to pigeon: enlargement, disciplined, ballot, hm, feuerbach, modena, visibly, categories,
# Nearest to tree: stalled, disquieting, tennant, lyndanisse, billion, dropped, lampooned, stimulation,
# Nearest to flower: stalk, emptying, avengers, exarchate, timbre, lt, fearsome, bearshare,
# Nearest to grass: marvellous, dreamed, pred, cravings, incident, avenger, simplifies, ndez,
# Nearest to apple: struma, distancing, lakewood, melancholy, planetoid, printer, try, borough,
# Nearest to orange: beagle, kwanzas, shamir, sabah, propped, irrelevent, adhesion, funneled,
# Nearest to grape: kyushu, chiles, cat, winkler, framers, hamilton, narratives, calvert,
# Nearest to red: distorting, motown, elements, tunnels, bumper, player, greasy, glaad,
# Nearest to green: quite, cidre, mixes, alcidamas, disagree, tinted, deprogrammings, haredim,
# Nearest to yellow: canonical, attainder, mediocre, newstead, animator, luftwaffe, malay, congreso,
# Nearest to blue: dynamics, powders, confectionery, faiths, whereby, hereby, photos, dexter,
# Nearest to dark: resting, goofy, apparition, slept, kur, murdoch, wotan, addis,
# Nearest to sun: innocuous, void, magnetosphere, rumored, carbons, venerated, varied, xii,
# Nearest to earth: fires, fermium, transcend, bands, intact, competence, foundational, humphry,
# Nearest to mars: tezuka, rdoba, supernaturally, covers, innocence, kylix, anguish, prince,
# Nearest to moon: maxfield, inoffensive, torvalds, nitrogen, sncf, track, ld, subsidized,
# Nearest to universe: ugly, councils, poissy, laissez, tubular, pulcher, lifetimes, liturgies,
# Nearest to water: p, wandering, estimating, approximation, comintern, surjective, sepsis, channing,
# Nearest to fire: searchers, sorry, autism, adverse, prisoners, wichita, rudin, harmonics,
# Nearest to stone: washtenaw, inquisition, fork, lifelong, misunderstanding, oxidise, pale, spy,
# Nearest to run: thirtieth, woke, substitutes, plaintiffs, gravitons, rvi, alaric, survives,
# Nearest to walk: accessories, burgundy, timeaxis, eucharist, tsar, townships, nuns, grained,
# Nearest to crawl: employment, northwestern, paleontologists, yachts, functionalities, beds, lysis, explicitly,
# Nearest to jump: pleasantville, thigh, javan, spirit, riding, lifes, unethical, kd,
# Nearest to jog: republik, radclyffe, interviewed, strewn, certificate, embouchure, resembled, funchal,
# Nearest to food: glaciated, joni, body, emphasising, alcs, czar, poetic, expansionary,
# Nearest to meal: lurker, coherent, v, sinners, semple, deregulated, gorgeous, substantiated,
# Nearest to breakfast: obscure, vbscript, windsor, viceroyalty, globe, integrate, adjacent, uncanonical,
# Nearest to lunch: environment, sinuous, scorecard, demonology, rhea, afp, sharp, anywhere,
# Nearest to dinner: dream, thinking, jute, filmmaker, kline, giri, vitamin, abstractly,
# Nearest to meat: convey, ambition, olympic, chrismation, locomotives, glasnost, keynesian, sabbats,
# Nearest to rice: illustrates, represents, ranged, reiterates, kilogram, defeat, felicity, mps,
# Nearest to vegetable: financing, frontend, nasi, rascal, trypomastigotes, vertigo, blackburn, ming,
# Nearest to love: jule, jock, hornet, theorem, motivation, rediffusion, unrounded, juxtaposition,
# Nearest to hate: accumulates, skeptics, awful, claimed, disciplined, holes, runequest, princeton,
# Nearest to kiss: chaos, immediate, stunted, resume, oshawa, faults, preliminary, skyline,
# Nearest to kill: lusaka, aides, assigning, woo, elmo, racquetball, deptford, as,
# Nearest to war: paleogeography, obsession, screenname, eldridge, gained, flushing, cathedral, suspension,
# Nearest to peace: lecter, fall, elector, carvin, gnu, restrictions, improvisation, trampled,
# Nearest to machine: arbitrator, intermediaries, points, outflows, krafft, eph, psychosis, substituting,
# Nearest to country: codebreaking, binghamton, importance, proton, pembroke, needs, montoneros, ses,
# Nearest to china: rmb, defeating, pens, dilbert, pervasive, clergyman, revolutionary, bikers,
# Nearest to america: washington, antonio, than, posts, tiberian, compromised, co, holiday,
# Nearest to korean: tampa, wave, journalist, diameter, alter, ral, dairies, oka,
# Nearest to russia: pronouns, murray, dulcimer, lapland, parallelism, narratives, algorithmic, suiko,
# Nearest to german: amputee, wiley, sensor, endeavoring, plosive, didache, gab, itching,
# Nearest to spain: football, multiplier, lengthening, refugees, six, eject, fujiwara, abdicate,
# Nearest to brazil: militarist, interfered, sentenced, tans, wilkeson, massacred, czechs, steinbeck,
# Epoch 1/6 Iteration: 4100 Avg. Training loss: 4.6567 0.0940 sec/batch
# Epoch 1/6 Iteration: 4200 Avg. Training loss: 4.6747 0.0900 sec/batch
# Epoch 1/6 Iteration: 4300 Avg. Training loss: 4.6159 0.0909 sec/batch
# Epoch 1/6 Iteration: 4400 Avg. Training loss: 4.6452 0.0904 sec/batch
# Epoch 1/6 Iteration: 4500 Avg. Training loss: 4.6358 0.0899 sec/batch
# Epoch 1/6 Iteration: 4600 Avg. Training loss: 4.6323 0.0905 sec/batch
# Epoch 2/6 Iteration: 4700 Avg. Training loss: 4.6354 0.0670 sec/batch
# Epoch 2/6 Iteration: 4800 Avg. Training loss: 4.5409 0.0905 sec/batch
# Epoch 2/6 Iteration: 4900 Avg. Training loss: 4.5235 0.0895 sec/batch
# Epoch 2/6 Iteration: 5000 Avg. Training loss: 4.4929 0.0894 sec/batch
# Epoch 2/6 Iteration: 5100 Avg. Training loss: 4.5020 0.0894 sec/batch
# Epoch 2/6 Iteration: 5200 Avg. Training loss: 4.4965 0.0896 sec/batch
# Epoch 2/6 Iteration: 5300 Avg. Training loss: 4.4503 0.0901 sec/batch
# Epoch 2/6 Iteration: 5400 Avg. Training loss: 4.5107 0.0898 sec/batch
# Epoch 2/6 Iteration: 5500 Avg. Training loss: 4.4846 0.0900 sec/batch
# Epoch 2/6 Iteration: 5600 Avg. Training loss: 4.4838 0.0916 sec/batch
# Epoch 2/6 Iteration: 5700 Avg. Training loss: 4.4336 0.0909 sec/batch
# Epoch 2/6 Iteration: 5800 Avg. Training loss: 4.4090 0.0912 sec/batch
# Epoch 2/6 Iteration: 5900 Avg. Training loss: 4.4196 0.0912 sec/batch
# Epoch 2/6 Iteration: 6000 Avg. Training loss: 4.4321 0.0915 sec/batch
# Nearest to person: deceased, believed, musicals, me, stanley, chaucer, atahualpa, reinstating,
# Nearest to people: kowalski, guerrilla, blend, reemerged, remove, transitioning, leopards, phane,
# Nearest to human: supra, conductors, duplicity, decreases, guerrilla, meles, dorians, antenna,
# Nearest to boy: ktav, develops, goodhue, flop, fdc, electromotive, balm, columnist,
# Nearest to girl: hendrik, internazionale, alcide, stirrup, oscar, anton, champions, maitre,
# Nearest to man: flesh, outlook, castilian, deserving, organists, tasmania, alomari, surfer,
# Nearest to woman: belisarius, sailboats, ready, aiken, slum, kelsey, ppe, putting,
# Nearest to baby: emphasising, legitimizing, amigos, interpolations, assure, cambridgeshire, federer, bricks,
# Nearest to father: goiter, preacher, him, rhodesia, jesus, darstellende, invoking, satirists,
# Nearest to mother: luba, raza, impeached, shipyard, jeroboam, pompeius, mahommed, relieved,
# Nearest to king: van, son, reign, andromache, lamp, roman, plan, aeschylus,
# Nearest to queen: golden, normalcy, hast, weaver, drexel, hogarth, reaffirmed, nota,
# Nearest to prince: roman, shehri, veneto, mansfield, connor, coughlin, mars, aylmer,
# Nearest to princess: ole, gp, felix, mug, dmitri, antiochus, livingston, impassioned,
# Nearest to general: fireballs, interferes, buck, prot, pyramids, zeitschrift, kevorkian, gilder,
# Nearest to soldier: composer, medallion, indian, wreckage, palestrina, multitudes, villain, salesman,
# Nearest to dog: porphyry, tyrants, variant, vivre, cyclopes, leavitt, perspiration, tion,
# Nearest to pig: forsythe, aureus, outputting, addicts, asphyxiation, shaded, shortened, risen,
# Nearest to cat: gotcha, grape, sociologists, upset, romances, softening, searle, vacancy,
# Nearest to mouse: deterred, taoists, moog, burghers, advertisements, stimuli, smegma, typify,
# Nearest to fish: throwers, unconfirmed, concocted, abbotsford, gradient, unloaded, southwest, conti,
# Nearest to bird: prehispanic, spotted, bedford, rak, surveyed, greig, naa, predator,
# Nearest to eagle: salamis, crimes, centre, saavedra, suitors, thwarting, facemask, crowley,
# Nearest to pigeon: enlargement, disciplined, ballot, hm, turtle, feuerbach, modena, categories,
# Nearest to tree: disquieting, stalled, tennant, billion, lyndanisse, lampooned, dropped, ac,
# Nearest to flower: stalk, avengers, emptying, exarchate, can, stewardship, timbre, executioner,
# Nearest to grass: marvellous, pred, dreamed, courses, crippling, ndez, avenger, incident,
# Nearest to apple: printer, distancing, struma, maintenance, forensic, lakewood, microsoft, programming,
# Nearest to orange: beagle, kwanzas, sabah, shamir, propped, mechanosynthesis, funneled, belles,
# Nearest to grape: kyushu, winkler, cat, chiles, framers, hamilton, narratives, calvert,
# Nearest to red: glaad, player, motown, sambia, greasy, distorting, thory, pacified,
# Nearest to green: cidre, sideband, poster, mixes, quite, tinted, deprogrammings, perkin,
# Nearest to yellow: canonical, attainder, malay, newstead, twickenham, judged, bruised, congreso,
# Nearest to blue: confectionery, conglomerate, dynamics, kimbundu, formants, noetherian, hereby, inadmissible,
# Nearest to dark: apparition, goofy, resting, kur, nicomedia, slept, swingarm, wotan,
# Nearest to sun: magnetosphere, innocuous, venerated, carbons, rumored, void, ultraman, varied,
# Nearest to earth: surface, transcend, dielectrics, humphry, enzymes, fused, tundra, demigod,
# Nearest to mars: tezuka, rdoba, kylix, bambi, supernaturally, covers, anguish, innocence,
# Nearest to moon: maxfield, inoffensive, nitrogen, ld, sncf, track, subsidized, convoluted,
# Nearest to universe: ugly, poissy, councils, tubular, laissez, pulcher, liturgies, lifetimes,
# Nearest to water: p, surjective, layer, approximation, estimating, comintern, liters, wandering,
# Nearest to fire: autism, searchers, sorry, harmonics, adverse, adhesive, defintion, hiberno,
# Nearest to stone: washtenaw, inquisition, voivodship, eagerness, fork, misunderstanding, oxidise, pale,
# Nearest to run: woke, users, thirtieth, substitutes, plaintiffs, gravitons, survives, alaric,
# Nearest to walk: timeaxis, accessories, tsar, nuns, shakespeare, webmasters, axiomatic, pseudalopex,
# Nearest to crawl: employment, functionalities, northwestern, yachts, lysis, paleontologists, separate, restarts,
# Nearest to jump: pleasantville, thigh, javan, spirit, lifes, kd, riding, corelli,
# Nearest to jog: republik, radclyffe, strewn, interviewed, certificate, embouchure, funchal, resembled,
# Nearest to food: glaciated, soda, body, than, incurred, silo, perceived, fireside,
# Nearest to meal: lurker, semple, gorgeous, sinners, coherent, telescope, deregulated, substantiated,
# Nearest to breakfast: obscure, viceroyalty, vbscript, globe, adjacent, unedited, windsor, uncanonical,
# Nearest to lunch: scorecard, sinuous, demonology, rhea, environment, afp, sasha, sharp,
# Nearest to dinner: jute, dream, thinking, filmmaker, kline, giri, vitamin, abstractly,
# Nearest to meat: convey, chrismation, ambition, sabbats, iterating, glasnost, locomotives, cereal,
# Nearest to rice: illustrates, represents, reiterates, ranged, technician, dorms, kilogram, timpani,
# Nearest to vegetable: financing, rascal, frontend, trypomastigotes, nasi, vertigo, kouchner, enrolling,
# Nearest to love: jule, jock, rediffusion, impassioned, hornet, juxtaposition, thomas, conservatorium,
# Nearest to hate: accumulates, awful, skeptics, claimed, runequest, disciplined, ungodly, holes,
# Nearest to kiss: chaos, immediate, resume, stunted, oshawa, team, infidel, trilobite,
# Nearest to kill: lusaka, aides, woo, elmo, awash, yoruba, racquetball, drawbacks,
# Nearest to war: paleogeography, obsession, screenname, gained, macbeth, vetoed, eldridge, laos,
# Nearest to peace: lecter, fall, governor, elector, carvin, napoleon, cassady, stilwell,
# Nearest to machine: trivial, architectures, arbitrator, points, substituting, heme, outflows, arbitrio,
# Nearest to country: binghamton, codebreaking, camino, montoneros, oman, ses, major, landlocked,
# Nearest to china: rmb, bikers, market, freising, defeating, dilbert, guns, positing,
# Nearest to america: antonio, washington, polyamory, than, holiday, posts, amigaone, tanlin,
# Nearest to korean: tampa, journalist, ral, dairies, oka, emmanuelle, indomitable, san,
# Nearest to russia: pronouns, nter, dulcimer, lapland, derails, westphalian, suiko, murray,
# Nearest to german: amputee, endeavoring, wiley, marlene, voor, coronations, eight, plosive,
# Nearest to spain: refugees, pannonia, football, six, lengthening, carmack, abdicate, trophyless,
# Nearest to brazil: militarist, massacred, interfered, wilkeson, czechs, tans, sentenced, netherlands,
# Epoch 2/6 Iteration: 6100 Avg. Training loss: 4.4028 0.0954 sec/batch
# Epoch 2/6 Iteration: 6200 Avg. Training loss: 4.4222 0.0906 sec/batch
# Epoch 2/6 Iteration: 6300 Avg. Training loss: 4.4067 0.0907 sec/batch
# Epoch 2/6 Iteration: 6400 Avg. Training loss: 4.3857 0.0909 sec/batch
# Epoch 2/6 Iteration: 6500 Avg. Training loss: 4.4130 0.0904 sec/batch
# Epoch 2/6 Iteration: 6600 Avg. Training loss: 4.4508 0.0903 sec/batch
# Epoch 2/6 Iteration: 6700 Avg. Training loss: 4.3807 0.0900 sec/batch
# Epoch 2/6 Iteration: 6800 Avg. Training loss: 4.3678 0.0902 sec/batch
# Epoch 2/6 Iteration: 6900 Avg. Training loss: 4.4151 0.0901 sec/batch
# Epoch 2/6 Iteration: 7000 Avg. Training loss: 4.3737 0.0903 sec/batch
# Epoch 2/6 Iteration: 7100 Avg. Training loss: 4.3991 0.0900 sec/batch
# Epoch 2/6 Iteration: 7200 Avg. Training loss: 4.4072 0.0900 sec/batch
# Epoch 2/6 Iteration: 7300 Avg. Training loss: 4.3683 0.0906 sec/batch
# Epoch 2/6 Iteration: 7400 Avg. Training loss: 4.3754 0.0902 sec/batch
# Epoch 2/6 Iteration: 7500 Avg. Training loss: 4.3961 0.0898 sec/batch
# Epoch 2/6 Iteration: 7600 Avg. Training loss: 4.3719 0.0900 sec/batch
# Epoch 2/6 Iteration: 7700 Avg. Training loss: 4.3867 0.0899 sec/batch
# Epoch 2/6 Iteration: 7800 Avg. Training loss: 4.4145 0.0902 sec/batch
# Epoch 2/6 Iteration: 7900 Avg. Training loss: 4.3330 0.0907 sec/batch
# Epoch 2/6 Iteration: 8000 Avg. Training loss: 4.3317 0.0910 sec/batch
# Nearest to person: deceased, believed, chaucer, sentences, musicals, spend, me, atahualpa,
# Nearest to people: kowalski, reemerged, guerrilla, leopards, blend, licence, transitioning, remove,
# Nearest to human: supra, conductors, dorians, duplicity, tomcats, decreases, issues, ammo,
# Nearest to boy: develops, ktav, fdc, electromotive, plots, flop, columnist, profiles,
# Nearest to girl: hendrik, stirrup, maitre, alcide, internazionale, oscar, soul, courting,
# Nearest to man: flesh, deserving, manichaeism, surfer, athenaeus, tasmania, pregnant, folklore,
# Nearest to woman: belisarius, slum, aiken, ready, unhappy, putting, life, sailboats,
# Nearest to baby: emphasising, amigos, legitimizing, interpolations, assure, federer, cambridgeshire, frink,
# Nearest to father: preacher, him, goiter, invoking, spiritual, jesus, satirists, bandleaders,
# Nearest to mother: luba, shipyard, raza, mahommed, pompeius, jeroboam, impeached, gneisenau,
# Nearest to king: reign, son, overbeck, lamp, throne, andromache, van, millennia,
# Nearest to queen: golden, normalcy, drexel, archdeacon, reaffirmed, princess, nota, hast,
# Nearest to prince: roman, veneto, hengest, shehri, septuagint, dallas, coughlin, failed,
# Nearest to princess: ole, felix, antiochus, mug, mclean, queen, gp, halle,
# Nearest to general: fireballs, bromide, interferes, joanne, octahedron, paging, presently, gilder,
# Nearest to soldier: composer, palestrina, medallion, wreckage, multitudes, uscis, ttel, courtier,
# Nearest to dog: variant, vivre, porphyry, tyrants, cyclopes, perspiration, goat, leavitt,
# Nearest to pig: forsythe, shortened, outputting, aureus, flavian, asphyxiation, tondino, addicts,
# Nearest to cat: gotcha, grape, sociologists, upset, searle, softening, romances, commonly,
# Nearest to mouse: deterred, taoists, moog, stimuli, advertisements, smegma, burghers, appears,
# Nearest to fish: unconfirmed, throwers, gradient, abbotsford, sustainable, concocted, celera, southwest,
# Nearest to bird: prehispanic, greig, naa, surveyed, predator, spotted, bedford, reader,
# Nearest to eagle: saavedra, salamis, crimes, facemask, suitors, centre, crowley, trinidad,
# Nearest to pigeon: enlargement, disciplined, categories, turtle, ballot, modena, visibly, patrimony,
# Nearest to tree: stalled, disquieting, tennant, lyndanisse, billion, lampooned, dropped, ac,
# Nearest to flower: stalk, emptying, avengers, exarchate, can, stewardship, sprays, operatic,
# Nearest to grass: marvellous, courses, pred, dreamed, cravings, crippling, upland, charterer,
# Nearest to apple: printer, microsoft, macintosh, distancing, struma, released, lakewood, programming,
# Nearest to orange: beagle, kwanzas, sabah, shamir, mechanosynthesis, belles, leaven, clarkson,
# Nearest to grape: kyushu, winkler, cat, chiles, framers, hamilton, calvert, narratives,
# Nearest to red: glaad, motown, greasy, sambia, player, bumper, tunnels, acerbic,
# Nearest to green: cidre, mixes, anaconda, poster, deprogrammings, sideband, tinted, vault,
# Nearest to yellow: bruised, yellowish, attainder, malay, compounds, rotors, deep, weaker,
# Nearest to blue: conglomerate, confectionery, kimbundu, dynamics, noetherian, dexter, formants, bars,
# Nearest to dark: resting, goofy, apparition, swingarm, kur, chlamydia, directorship, nicomedia,
# Nearest to sun: magnetosphere, innocuous, carbons, venerated, rumored, atmosphere, strawson, ultraman,
# Nearest to earth: surface, dielectrics, toontown, enzymes, transcend, humphry, fused, tundra,
# Nearest to mars: tezuka, rdoba, kylix, bambi, supernaturally, joaquin, mussels, endometrium,
# Nearest to moon: maxfield, ld, inoffensive, track, sncf, nitrogen, husks, qigong,
# Nearest to universe: ugly, poissy, tubular, councils, laissez, paintings, liturgies, pulcher,
# Nearest to water: salt, liters, layer, p, surjective, fe, aromatic, estimating,
# Nearest to fire: searchers, autism, infantry, sorry, hermon, demolishing, adhesive, misdiagnosed,
# Nearest to stone: washtenaw, eagerness, fork, hopping, voivodship, inquisition, ofc, wootz,
# Nearest to run: users, woke, sold, substitutes, block, usb, sld, thirtieth,
# Nearest to walk: timeaxis, accessories, shakespeare, tsar, pseudalopex, amex, spider, burgundy,
# Nearest to crawl: employment, functionalities, yachts, separate, paleontologists, michinaga, lysis, northwestern,
# Nearest to jump: pleasantville, thigh, javan, spirit, litre, lifes, riding, romanisation,
# Nearest to jog: republik, strewn, radclyffe, embouchure, resembled, funchal, interviewed, compressive,
# Nearest to food: sugar, soda, glaciated, dairy, silo, body, expansionary, regrowth,
# Nearest to meal: gorgeous, lurker, semple, sinners, telescope, assimilation, deregulated, kam,
# Nearest to breakfast: obscure, windsor, unedited, globe, vbscript, viceroyalty, awry, gr,
# Nearest to lunch: sinuous, rhea, scorecard, demonology, sasha, afp, curious, sharp,
# Nearest to dinner: jute, dream, filmmaker, thinking, kline, giri, udall, vitamin,
# Nearest to meat: convey, sabbats, chrismation, cereal, food, iterating, professions, blau,
# Nearest to rice: illustrates, represents, technician, reiterates, ranged, sar, timpani, extracting,
# Nearest to vegetable: rascal, fruits, financing, trypomastigotes, frontend, cooler, nasi, vertigo,
# Nearest to love: jule, jock, juxtaposition, songs, rediffusion, havenco, me, passion,
# Nearest to hate: accumulates, awful, claimed, skeptics, runequest, ungodly, princeton, disciplined,
# Nearest to kiss: chaos, stunted, immediate, oshawa, incriminate, infidel, team, squeak,
# Nearest to kill: lusaka, aides, woo, elmo, him, awash, killing, yoruba,
# Nearest to war: paleogeography, obsession, macbeth, screenname, laos, defeated, gained, roundhouse,
# Nearest to peace: lecter, fall, governor, elector, napoleon, stilwell, cassady, martel,
# Nearest to machine: architectures, interpreter, microprocessor, arbitrator, trivial, arbitrio, decode, intermediaries,
# Nearest to country: codebreaking, binghamton, oman, camino, montoneros, tajikistan, pembroke, landlocked,
# Nearest to china: rmb, bikers, taiwan, freising, suriname, revolutionary, market, cienfuegos,
# Nearest to america: than, polyamory, antonio, amigaone, washington, holiday, tanlin, suez,
# Nearest to korean: tampa, emmanuelle, ral, dairies, roebuck, varma, journalist, indomitable,
# Nearest to russia: lapland, derails, westphalian, suiko, nter, pronouns, principality, silvanus,
# Nearest to german: amputee, endeavoring, germanic, coronations, schleicher, css, lissajous, voor,
# Nearest to spain: refugees, pannonia, fujiwara, trophyless, abdicate, carmack, border, six,
# Nearest to brazil: militarist, massacred, netherlands, wilkeson, czechs, interfered, tans, nationalities,
# Epoch 2/6 Iteration: 8100 Avg. Training loss: 4.3728 0.0958 sec/batch
# Epoch 2/6 Iteration: 8200 Avg. Training loss: 4.2937 0.0906 sec/batch
# Epoch 2/6 Iteration: 8300 Avg. Training loss: 4.3833 0.0912 sec/batch
# Epoch 2/6 Iteration: 8400 Avg. Training loss: 4.3739 0.0908 sec/batch
# Epoch 2/6 Iteration: 8500 Avg. Training loss: 4.3866 0.0908 sec/batch
# Epoch 2/6 Iteration: 8600 Avg. Training loss: 4.2867 0.0906 sec/batch
# Epoch 2/6 Iteration: 8700 Avg. Training loss: 4.2933 0.0902 sec/batch
# Epoch 2/6 Iteration: 8800 Avg. Training loss: 4.3292 0.0907 sec/batch
# Epoch 2/6 Iteration: 8900 Avg. Training loss: 4.2477 0.0914 sec/batch
# Epoch 2/6 Iteration: 9000 Avg. Training loss: 4.2838 0.0913 sec/batch
# Epoch 2/6 Iteration: 9100 Avg. Training loss: 4.3137 0.0900 sec/batch
# Epoch 2/6 Iteration: 9200 Avg. Training loss: 4.3068 0.0895 sec/batch
# Epoch 3/6 Iteration: 9300 Avg. Training loss: 4.3062 0.0436 sec/batch
# Epoch 3/6 Iteration: 9400 Avg. Training loss: 4.2614 0.0909 sec/batch
# Epoch 3/6 Iteration: 9500 Avg. Training loss: 4.2483 0.0898 sec/batch
# Epoch 3/6 Iteration: 9600 Avg. Training loss: 4.1939 0.0893 sec/batch
# Epoch 3/6 Iteration: 9700 Avg. Training loss: 4.2208 0.0897 sec/batch
# Epoch 3/6 Iteration: 9800 Avg. Training loss: 4.2007 0.0899 sec/batch
# Epoch 3/6 Iteration: 9900 Avg. Training loss: 4.2187 0.0895 sec/batch
# Epoch 3/6 Iteration: 10000 Avg. Training loss: 4.1863 0.0904 sec/batch
# Nearest to person: deceased, chaucer, sentences, atahualpa, believed, reinstating, spend, musicals,
# Nearest to people: kowalski, reemerged, guerrilla, blend, leopards, native, remove, coherence,
# Nearest to human: supra, decreases, dorians, duplicity, clinicians, conductors, inheritors, issues,
# Nearest to boy: develops, ktav, flop, goodhue, columnist, passim, fdc, advance,
# Nearest to girl: hendrik, alcide, pseudonym, stirrup, maitre, internazionale, oscar, elgar,
# Nearest to man: flesh, deserving, pregnant, manichaeism, athenaeus, intramural, bunyan, alomari,
# Nearest to woman: unhappy, belisarius, aiken, slum, her, life, ready, childbirth,
# Nearest to baby: emphasising, amigos, interpolations, legitimizing, clock, frink, astounding, impaled,
# Nearest to father: him, preacher, goiter, preach, satirists, spiritual, invoking, maternal,
# Nearest to mother: luba, pompeius, shipyard, raza, jeroboam, mahommed, seventeen, branagh,
# Nearest to king: son, throne, reign, andromache, overbeck, bernard, zajdel, aeschylus,
# Nearest to queen: golden, archdeacon, princess, reaffirmed, normalcy, nota, drexel, weaver,
# Nearest to prince: veneto, hengest, coughlin, aylmer, schickele, tsonga, connor, failed,
# Nearest to princess: ole, queen, felix, mug, mclean, antiochus, gp, livingston,
# Nearest to general: fireballs, interferes, douglas, oates, joanne, buck, dots, tutors,
# Nearest to soldier: composer, ttel, palestrina, wreckage, courtier, medallion, multitudes, gonzalez,
# Nearest to dog: variant, vivre, goat, porphyry, wha, leavitt, cyclopes, example,
# Nearest to pig: forsythe, shortened, outputting, aureus, risen, asphyxiation, addicts, tondino,
# Nearest to cat: gotcha, grape, upset, searle, romances, commonly, lectionis, unlucky,
# Nearest to mouse: advertisements, deterred, stimuli, taoists, moog, smegma, jaeger, jeremy,
# Nearest to fish: unconfirmed, throwers, sustainable, reptiles, abbotsford, gradient, woodland, cuisine,
# Nearest to bird: predator, prehispanic, spotted, naa, greig, microscopic, embankments, larvae,
# Nearest to eagle: saavedra, salamis, suitors, facemask, named, oversized, bicycle, crimes,
# Nearest to pigeon: disciplined, categories, enlargement, turtle, modena, msm, ballot, salut,
# Nearest to tree: disquieting, tennant, stalled, lyndanisse, shine, nouveau, marchibroda, originating,
# Nearest to flower: stalk, emptying, avengers, exarchate, smell, can, sprays, purple,
# Nearest to grass: marvellous, courses, dreamed, pred, crippling, upland, deepwater, hgh,
# Nearest to apple: printer, macintosh, released, distancing, microsoft, lakewood, inc, forensic,
# Nearest to orange: beagle, sabah, kwanzas, mechanosynthesis, leaven, shamir, belles, turbines,
# Nearest to grape: kyushu, winkler, chiles, cat, framers, hamilton, naturally, calvert,
# Nearest to red: glaad, sambia, motown, greasy, phosphatase, tunnels, wco, inundation,
# Nearest to green: cidre, anaconda, mixes, mammals, tinted, poster, deprogrammings, sideband,
# Nearest to yellow: bruised, yellowish, malay, attainder, erechtheus, rotors, deep, andersen,
# Nearest to blue: conglomerate, formants, confectionery, kimbundu, bars, wearing, dexter, shirt,
# Nearest to dark: swingarm, goofy, resting, directorship, kur, apparition, yeah, slept,
# Nearest to sun: magnetosphere, venerated, innocuous, rumored, atmosphere, strawson, carbons, ultraman,
# Nearest to earth: surface, dielectrics, toontown, humphry, demigod, tundra, radiotelephone, fermium,
# Nearest to mars: tezuka, rdoba, kylix, bambi, joaquin, huygens, tilted, upc,
# Nearest to moon: maxfield, ld, track, inoffensive, sncf, dark, nitrogen, plait,
# Nearest to universe: ugly, poissy, tubular, paintings, earthenware, pulcher, lifetimes, musicianship,
# Nearest to water: salt, liters, layer, surjective, gum, twitch, fe, aromatic,
# Nearest to fire: searchers, autism, infantry, hermon, demolishing, adhesive, lightly, sorry,
# Nearest to stone: fork, eagerness, washtenaw, pale, hopping, biarritz, ofc, stacking,
# Nearest to run: users, block, sold, usb, sld, woke, soldering, hub,
# Nearest to walk: timeaxis, accessories, pseudalopex, spider, shakespeare, tsar, arch, penetrating,
# Nearest to crawl: employment, functionalities, ailment, michinaga, yachts, lysis, credibility, paleontologists,
# Nearest to jump: pleasantville, thigh, litre, javan, riding, spirit, lifes, corelli,
# Nearest to jog: republik, strewn, radclyffe, funchal, embouchure, compressive, resembled, cowell,
# Nearest to food: sugar, soda, dairy, glaciated, expansionary, fossil, meat, feed,
# Nearest to meal: gorgeous, lurker, semple, eat, assimilation, sinners, subgenre, septicemic,
# Nearest to breakfast: globe, unedited, obscure, windsor, viceroyalty, awry, vbscript, gr,
# Nearest to lunch: rhea, sinuous, scorecard, demonology, sasha, curious, killer, cheers,
# Nearest to dinner: jute, dream, filmmaker, kline, thinking, giri, udall, deconstructing,
# Nearest to meat: convey, chrismation, cereal, sabbats, food, grapes, allergy, nuts,
# Nearest to rice: illustrates, technician, sar, represents, reiterates, shale, electricity, sieve,
# Nearest to vegetable: fruits, rascal, trypomastigotes, financing, piles, cooler, desserts, soi,
# Nearest to love: jule, songs, jock, havenco, passion, rediffusion, me, juxtaposition,
# Nearest to hate: accumulates, awful, claimed, skeptics, runequest, ungodly, princeton, custodial,
# Nearest to kiss: chaos, stunted, immediate, infidel, incriminate, resume, oshawa, earthlike,
# Nearest to kill: him, killing, lusaka, aides, awash, woo, elmo, girl,
# Nearest to war: paleogeography, macbeth, obsession, screenname, laos, starlink, eldridge, roundhouse,
# Nearest to peace: lecter, stilwell, elector, fall, cassady, engrailed, martel, unrepresented,
# Nearest to machine: arbitrator, architectures, interpreter, arbitrio, microprocessor, derivative, trivial, intermediaries,
# Nearest to country: oman, landlocked, camino, tajikistan, binghamton, codebreaking, montoneros, major,
# Nearest to china: rmb, bikers, taiwan, freising, cienfuegos, vidarbha, xuan, guns,
# Nearest to america: than, amigaone, dataran, tanlin, polyamory, holiday, johnstone, posts,
# Nearest to korean: tampa, emmanuelle, dairies, roebuck, kul, ral, varma, indomitable,
# Nearest to russia: westphalian, lapland, derails, pronouns, suiko, bal, silvanus, neisse,
# Nearest to german: endeavoring, germany, css, germanic, amputee, eight, lissajous, voor,
# Nearest to spain: refugees, pannonia, trophyless, fujiwara, abdicate, carmack, episkopos, portugal,
# Nearest to brazil: militarist, uruguay, ppp, czechs, tans, netherlands, interfered, wilkeson,
# Epoch 3/6 Iteration: 10100 Avg. Training loss: 4.2585 0.0945 sec/batch
# Epoch 3/6 Iteration: 10200 Avg. Training loss: 4.2206 0.0907 sec/batch
# Epoch 3/6 Iteration: 10300 Avg. Training loss: 4.1751 0.0904 sec/batch
# Epoch 3/6 Iteration: 10400 Avg. Training loss: 4.1350 0.0914 sec/batch
# Epoch 3/6 Iteration: 10500 Avg. Training loss: 4.1703 0.0916 sec/batch
# Epoch 3/6 Iteration: 10600 Avg. Training loss: 4.1776 0.0924 sec/batch
# Epoch 3/6 Iteration: 10700 Avg. Training loss: 4.1550 0.0906 sec/batch
# Epoch 3/6 Iteration: 10800 Avg. Training loss: 4.1868 0.0912 sec/batch
# Epoch 3/6 Iteration: 10900 Avg. Training loss: 4.2238 0.0905 sec/batch
# Epoch 3/6 Iteration: 11000 Avg. Training loss: 4.1902 0.0916 sec/batch
# Epoch 3/6 Iteration: 11100 Avg. Training loss: 4.1779 0.0903 sec/batch
# Epoch 3/6 Iteration: 11200 Avg. Training loss: 4.2146 0.0904 sec/batch
# Epoch 3/6 Iteration: 11300 Avg. Training loss: 4.1724 0.0907 sec/batch
# Epoch 3/6 Iteration: 11400 Avg. Training loss: 4.1485 0.0914 sec/batch
# Epoch 3/6 Iteration: 11500 Avg. Training loss: 4.2130 0.0903 sec/batch
# Epoch 3/6 Iteration: 11600 Avg. Training loss: 4.1803 0.0903 sec/batch
# Epoch 3/6 Iteration: 11700 Avg. Training loss: 4.2232 0.0900 sec/batch
# Epoch 3/6 Iteration: 11800 Avg. Training loss: 4.1635 0.0898 sec/batch
# Epoch 3/6 Iteration: 11900 Avg. Training loss: 4.1419 0.0904 sec/batch
# Epoch 3/6 Iteration: 12000 Avg. Training loss: 4.1791 0.0904 sec/batch
# Nearest to person: deceased, chaucer, sentences, reinstating, atahualpa, spend, musicals, me,
# Nearest to people: kowalski, guerrilla, reemerged, native, writers, living, licence, leopards,
# Nearest to human: supra, dorians, duplicity, issues, dispositions, clinicians, inheritors, decreases,
# Nearest to boy: advance, flop, develops, profiles, unreliable, trance, electromotive, goodhue,
# Nearest to girl: hendrik, kill, maitre, stirrup, soul, elgar, alcide, internazionale,
# Nearest to man: flesh, manichaeism, pregnant, lonely, athenaeus, bunyan, deserving, eastenders,
# Nearest to woman: slum, aiken, belisarius, unhappy, her, childbirth, life, putting,
# Nearest to baby: emphasising, amigos, legitimizing, interpolations, astounding, impaled, frink, bolted,
# Nearest to father: him, preach, preacher, invoking, siblings, maternal, goiter, nehemiah,
# Nearest to mother: luba, pompeius, shipyard, prosthesis, physically, folkloric, whatsoever, jeroboam,
# Nearest to king: throne, son, lamp, reign, zajdel, andromache, bernard, overbeck,
# Nearest to queen: golden, archdeacon, princess, normalcy, reaffirmed, weaver, drexel, nota,
# Nearest to prince: veneto, hengest, pretender, coughlin, tsonga, lobbies, schickele, deponent,
# Nearest to princess: ole, queen, gp, mug, antiochus, felix, beheaded, friendships,
# Nearest to general: fireballs, oates, douglas, interferes, dots, joanne, bromide, tacit,
# Nearest to soldier: composer, wreckage, palestrina, ttel, multitudes, courtier, outset, megaman,
# Nearest to dog: variant, goat, cyclopes, porphyry, wha, vivre, leavitt, tion,
# Nearest to pig: forsythe, risen, shortened, outputting, adl, asphyxiation, aureus, tondino,
# Nearest to cat: gotcha, grape, commonly, upset, unlucky, searle, romances, chambers,
# Nearest to mouse: stimuli, taoists, advertisements, moog, deterred, smegma, jeremy, appears,
# Nearest to fish: unconfirmed, reptiles, abbotsford, gradient, sustainable, celera, environmentalists, cuisine,
# Nearest to bird: predator, prehispanic, spotted, greig, naa, embankments, typecast, consanguinity,
# Nearest to eagle: salamis, saavedra, suitors, oversized, facemask, bicycle, infirmary, named,
# Nearest to pigeon: categories, turtle, disciplined, enlargement, salut, kista, msm, modena,
# Nearest to tree: stalled, disquieting, lyndanisse, tennant, originating, shine, pleasuredome, stowed,
# Nearest to flower: stalk, emptying, avengers, exarchate, smell, purple, haikai, sprays,
# Nearest to grass: marvellous, courses, upland, deepwater, dreamed, pred, hgh, crippling,
# Nearest to apple: printer, macintosh, distancing, released, forensic, lakewood, beccaria, decks,
# Nearest to orange: beagle, leaven, turbines, sabah, unexploited, mechanosynthesis, kwanzas, unlockable,
# Nearest to grape: kyushu, cat, winkler, chiles, framers, yeasts, cultivar, calvert,
# Nearest to red: glaad, motown, greasy, sambia, wco, scenes, acerbic, letterboxer,
# Nearest to green: cidre, anaconda, vault, poster, tinted, deprogrammings, emigr, electress,
# Nearest to yellow: yellowish, bruised, malay, deep, andersen, colour, seiya, erechtheus,
# Nearest to blue: shirt, bars, kimbundu, puckett, formants, conglomerate, confectionery, wearing,
# Nearest to dark: resting, swingarm, goofy, kur, moon, directorship, apparition, chlamydia,
# Nearest to sun: magnetosphere, venerated, atmosphere, innocuous, rumored, strawson, tuner, cloud,
# Nearest to earth: surface, dielectrics, toontown, demigod, equator, tundra, asteroid, humphry,
# Nearest to mars: tezuka, rdoba, joaquin, kylix, bambi, huygens, tilted, borrows,
# Nearest to moon: maxfield, ld, dark, inoffensive, plait, track, sncf, nitrogen,
# Nearest to universe: ugly, poissy, tubular, earthenware, mass, musicianship, councils, paintings,
# Nearest to water: liters, salt, nutrient, gum, layer, aromatic, sepsis, surjective,
# Nearest to fire: searchers, autism, infantry, demolishing, imagine, hermon, sorry, adhesive,
# Nearest to stone: fork, pale, eagerness, hopping, stacking, washtenaw, wyoming, corner,
# Nearest to run: block, sld, users, lawn, woke, furlongs, substitutes, pfeiffer,
# Nearest to walk: pseudalopex, timeaxis, accessories, spider, shakespeare, arch, tsar, hesitate,
# Nearest to crawl: functionalities, employment, lysis, yachts, michinaga, restarts, caa, paleontologists,
# Nearest to jump: pleasantville, litre, javan, thigh, riding, lifes, securely, spirit,
# Nearest to jog: strewn, republik, radclyffe, funchal, compressive, cyclops, resembled, cowell,
# Nearest to food: sugar, meat, dairy, soda, feed, regrowth, expansionary, broth,
# Nearest to meal: gorgeous, eat, semple, assimilation, septicemic, watery, inhaled, subgenre,
# Nearest to breakfast: globe, obscure, unedited, windsor, baseketball, awry, gr, taunted,
# Nearest to lunch: rhea, cheers, sinuous, scorecard, sasha, curious, killer, demonology,
# Nearest to dinner: jute, dream, filmmaker, kline, vitamin, giri, thinking, theater,
# Nearest to meat: food, cereal, nuts, grapes, vegetables, sabbats, convey, stews,
# Nearest to rice: technician, illustrates, sar, cereals, shale, electricity, gwh, imports,
# Nearest to vegetable: fruits, rascal, trypomastigotes, marinated, cassava, desserts, piles, butter,
# Nearest to love: jule, songs, havenco, passion, delany, hamlet, me, thomas,
# Nearest to hate: accumulates, awful, claimed, runequest, skeptics, ungodly, ephraim, miggins,
# Nearest to kiss: chaos, immediate, oshawa, resume, stunted, infidel, squeak, me,
# Nearest to kill: killing, lusaka, him, awash, girl, woo, aides, elmo,
# Nearest to war: paleogeography, obsession, screenname, macbeth, starlink, ncos, eldridge, laos,
# Nearest to peace: stilwell, lecter, elector, fall, unrepresented, martel, governor, erupted,
# Nearest to machine: arbitrator, interpreter, arbitrio, intermediaries, eph, derivative, architectures, cronin,
# Nearest to country: landlocked, oman, tajikistan, camino, binghamton, codebreaking, servitude, montoneros,
# Nearest to china: rmb, taiwan, bikers, freising, hun, xuan, tagalog, cienfuegos,
# Nearest to america: amigaone, johnstone, dataran, tanlin, than, tiberian, polyamory, jarrett,
# Nearest to korean: tampa, emmanuelle, roebuck, dairies, ral, varma, kul, journalist,
# Nearest to russia: westphalian, derails, neisse, lapland, bal, pronouns, nter, grenadines,
# Nearest to german: germany, germanic, lissajous, css, endeavoring, angelique, amputee, voor,
# Nearest to spain: refugees, pannonia, trophyless, fujiwara, portugal, deposed, episkopos, palaeologus,
# Nearest to brazil: militarist, tans, netherlands, czechs, ppp, uruguay, limburgish, slovaks,
# Epoch 3/6 Iteration: 12100 Avg. Training loss: 4.2149 0.0946 sec/batch
# Epoch 3/6 Iteration: 12200 Avg. Training loss: 4.1725 0.0903 sec/batch
# Epoch 3/6 Iteration: 12300 Avg. Training loss: 4.1896 0.0898 sec/batch
# ...
# Epoch 6/6 Iteration: 23300 Avg. Training loss: 3.9505 0.0906 sec/batch
# Epoch 6/6 Iteration: 23400 Avg. Training loss: 3.9604 0.0895 sec/batch
# Epoch 6/6 Iteration: 23500 Avg. Training loss: 3.9585 0.0892 sec/batch
# Epoch 6/6 Iteration: 23600 Avg. Training loss: 3.9154 0.0895 sec/batch
# Epoch 6/6 Iteration: 23700 Avg. Training loss: 3.9321 0.0896 sec/batch
# Epoch 6/6 Iteration: 23800 Avg. Training loss: 3.9096 0.0904 sec/batch
# Epoch 6/6 Iteration: 23900 Avg. Training loss: 3.9489 0.0902 sec/batch
# Epoch 6/6 Iteration: 24000 Avg. Training loss: 3.9595 0.0896 sec/batch
# Nearest to person: chaucer, embargo, deceased, caesura, meaninglessness, uneducated, sentences, environment,
# Nearest to people: living, writers, cayuga, native, ludendorff, bombings, kowalski, recommend,
# Nearest to human: supra, duplicity, humans, pose, animal, forebears, cogent, forty,
# Nearest to boy: advance, flop, ds, profiles, cursor, sentiment, nintendo, cartridge,
# Nearest to girl: maitre, drip, rah, pseudonym, numerological, keyhole, melodrama, thing,
# Nearest to man: flesh, lgbt, slave, manichaeism, awakened, afips, intergalactic, aegeas,
# Nearest to woman: her, childbirth, children, female, slum, caribou, hiv, belisarius,
# Nearest to baby: emphasising, amigos, legitimizing, vaccine, frink, saliva, nanook, impaled,
# Nearest to father: siblings, preach, son, admires, negligence, eldest, sod, him,
# Nearest to mother: her, husband, luba, wife, divorced, whatsoever, slaying, seventeen,
# Nearest to king: lamp, andromache, zajdel, genealogies, pomerania, throne, omri, reign,
# Nearest to queen: highness, golden, princess, archdeacon, warden, nota, weaver, klux,
# Nearest to prince: pretender, veneto, negligence, tsonga, coughlin, hengest, tabloid, ruthenia,
# Nearest to princess: queen, gp, skie, arnulf, ole, mug, unlockable, sterility,
# Nearest to general: southsea, sugar, yerba, referring, fireballs, whewell, nikolayevich, brigade,
# Nearest to soldier: wreckage, composer, eustace, ttel, ouen, royalist, ortelius, warlord,
# Nearest to dog: goat, variant, leavitt, porphyry, cyclopes, erectile, uh, wha,
# Nearest to pig: forsythe, risen, outputting, trees, adl, canned, aureus, words,
# Nearest to cat: gotcha, grape, commonly, grainger, romances, unlucky, arboreal, eros,
# Nearest to mouse: stimuli, deterred, appears, taoists, smegma, affectionate, leno, jeremy,
# Nearest to fish: chondrichthyes, crayfish, reptiles, sustainable, unconfirmed, abbotsford, cucumbers, plumage,
# Nearest to bird: predator, spotted, reader, plumage, subgenus, embankments, consanguinity, animals,
# Nearest to eagle: salamis, saavedra, polynesians, twig, spaceshipone, oversized, keegan, screech,
# Nearest to pigeon: turtle, categories, kista, salut, steller, daughters, ros, modena,
# Nearest to tree: constraint, ebcdic, dreher, amaterasu, changer, stowed, trees, simian,
# Nearest to flower: stalk, purple, smell, emptying, embankments, tes, haikai, flowers,
# Nearest to grass: marvellous, courses, pred, upland, findable, ndez, subdivision, carnivorous,
# Nearest to apple: macintosh, distancing, decks, released, lakewood, compuserve, powerbook, beccaria,
# Nearest to orange: excitation, sabah, leaven, beagle, white, yellow, logo, cyan,
# Nearest to grape: cat, framers, cultivar, kyushu, winkler, chiles, caucasian, yeasts,
# Nearest to red: byproduct, colors, glaad, wco, motown, greasy, color, blue,
# Nearest to green: tinted, purple, anaconda, merle, deprogrammings, bloc, cidre, electress,
# Nearest to yellow: yellowish, colour, colors, bruised, shade, pale, orange, pink,
# Nearest to blue: shirt, colored, shade, colors, wearing, red, mainstreaming, berenson,
# Nearest to dark: swingarm, goofy, joanna, apparition, kur, moon, stalagmites, abundances,
# Nearest to sun: magnetosphere, venerated, sidereal, centauri, cloud, incognita, observations, solar,
# Nearest to earth: surface, dielectrics, demigod, radiotelephone, fermium, asteroid, sidereal, intersputnik,
# Nearest to mars: tezuka, rdoba, orbiter, planetary, probe, bambi, tilted, huygens,
# Nearest to moon: maxfield, landing, plait, dark, ld, mankind, ecliptic, deucalion,
# Nearest to universe: ugly, cosmology, cosmic, councils, confront, accelerators, poissy, offeror,
# Nearest to water: liters, confessed, yoghurt, bogot, maturity, nutrient, acetone, layer,
# Nearest to fire: searchers, infantry, battalions, aikido, aspiration, dreamer, lawgiver, merlot,
# Nearest to stone: stacking, overgrown, decoration, barrows, neolithic, wootz, vico, biarritz,
# Nearest to run: runs, outfielder, substitutes, sld, dma, preinstalled, itanium, kentucky,
# Nearest to walk: robbie, slade, pseudalopex, relent, elect, funnel, timeaxis, gatwick,
# Nearest to crawl: functionalities, yachts, clockless, restarts, caa, coco, traynor, lysis,
# Nearest to jump: litre, pleasantville, thigh, javan, freefall, riding, corelli, spirit,
# Nearest to jog: funchal, republik, strewn, fulfil, enniskillen, ursa, radclyffe, cyclops,
# Nearest to food: broth, regrowth, meat, dopamine, osce, approved, feed, glaciated,
# Nearest to meal: meals, snack, choy, eat, gorgeous, semple, barn, cooked,
# Nearest to breakfast: cheesemaking, vbscript, ketchup, coconut, ohms, baseketball, awry, spandau,
# Nearest to lunch: rhea, scorecard, cheers, trademarked, matriarch, curious, cooking, unchained,
# Nearest to dinner: jute, filmmaker, bun, vitamin, udall, abstractly, dream, pinafore,
# Nearest to meat: cereal, pork, stews, dumplings, food, sabbats, grilled, soup,
# Nearest to rice: tofu, represents, uncooked, cuisines, technician, cereals, astin, ketchup,
# Nearest to vegetable: marinated, fruits, rascal, harry, desserts, butter, coenzyme, trypomastigotes,
# Nearest to love: songs, delany, passion, hamlet, havenco, me, jule, gonna,
# Nearest to hate: claimed, awful, accumulates, miggins, skeptics, rape, warfield, runequest,
# Nearest to kiss: resume, me, oshawa, sinners, immediate, jelly, lecter, bette,
# Nearest to kill: awash, killing, lusaka, fatally, aides, woo, elmo, kills,
# Nearest to war: obsession, ncos, macbeth, wars, screenname, paleogeography, heaviest, policemen,
# Nearest to peace: stilwell, oslo, stating, agreed, lecter, agreement, carvin, oligosaccharides,
# Nearest to machine: arbitrator, interpreter, eph, arbitrio, architectures, teutonic, trinidad, intermediaries,
# Nearest to country: landlocked, camino, servitude, rm, lunokhod, mitzvot, unexpired, codebreaking,
# Nearest to china: taiwan, yan, ming, hong, xuan, chinese, jurchen, han,
# Nearest to america: brazil, johnstone, fortes, countercultural, journal, amigaone, freedom, tam,
# Nearest to korean: loanwords, militant, varma, retroflex, kul, singapore, emmanuelle, tampa,
# Nearest to russia: russian, westphalian, soviet, neisse, henryk, aloha, hopkinson, lutheranism,
# Nearest to german: germany, css, ww, germanic, gustav, nach, townes, sabotaged,
# Nearest to spain: trophyless, portugal, unsurprisingly, spanish, redonda, nah, elish, carmack,
# Nearest to brazil: militarist, horizonte, slovaks, uruguay, santo, tans, czechs, netherlands,
# Epoch 6/6 Iteration: 24100 Avg. Training loss: 3.9585 0.0960 sec/batch
# Epoch 6/6 Iteration: 24200 Avg. Training loss: 3.9906 0.0909 sec/batch
# Epoch 6/6 Iteration: 24300 Avg. Training loss: 3.8459 0.0908 sec/batch
# Epoch 6/6 Iteration: 24400 Avg. Training loss: 3.9172 0.0915 sec/batch
# Epoch 6/6 Iteration: 24500 Avg. Training loss: 3.8816 0.0914 sec/batch
# Epoch 6/6 Iteration: 24600 Avg. Training loss: 3.8910 0.0908 sec/batch
# Epoch 6/6 Iteration: 24700 Avg. Training loss: 3.9242 0.0907 sec/batch
# Epoch 6/6 Iteration: 24800 Avg. Training loss: 3.9745 0.0908 sec/batch
# Epoch 6/6 Iteration: 24900 Avg. Training loss: 3.8968 0.0909 sec/batch
# Epoch 6/6 Iteration: 25000 Avg. Training loss: 3.9485 0.0898 sec/batch
# Epoch 6/6 Iteration: 25100 Avg. Training loss: 4.0128 0.0902 sec/batch
# Epoch 6/6 Iteration: 25200 Avg. Training loss: 3.8948 0.0905 sec/batch
# Epoch 6/6 Iteration: 25300 Avg. Training loss: 3.9310 0.0905 sec/batch
# Epoch 6/6 Iteration: 25400 Avg. Training loss: 3.9732 0.0907 sec/batch
# Epoch 6/6 Iteration: 25500 Avg. Training loss: 3.9305 0.0902 sec/batch
# Epoch 6/6 Iteration: 25600 Avg. Training loss: 3.9570 0.0905 sec/batch
# Epoch 6/6 Iteration: 25700 Avg. Training loss: 3.9766 0.0898 sec/batch
# Epoch 6/6 Iteration: 25800 Avg. Training loss: 3.9130 0.0902 sec/batch
# Epoch 6/6 Iteration: 25900 Avg. Training loss: 3.9309 0.0898 sec/batch
# Epoch 6/6 Iteration: 26000 Avg. Training loss: 3.9822 0.0902 sec/batch
# Nearest to person: chaucer, embargo, activision, caesura, environment, meaninglessness, gianfranco, conses,
# Nearest to people: living, cayuga, ludendorff, native, guerrilla, kowalski, recommend, letterman,
# Nearest to human: supra, duplicity, humans, cogent, dispositions, forebears, animal, forty,
# Nearest to boy: advance, ds, flop, cartridge, profiles, nintendo, cursor, autopilot,
# Nearest to girl: drip, maitre, rah, keyhole, melodrama, numerological, pseudonym, thing,
# Nearest to man: flesh, lgbt, awakened, afips, slave, manichaeism, intergalactic, adam,
# Nearest to woman: her, childbirth, caribou, female, children, slum, hiv, belisarius,
# Nearest to baby: emphasising, legitimizing, amigos, vaccine, saliva, nanook, interpolations, arsenio,
# Nearest to father: siblings, son, preach, negligence, admires, him, sod, agrippina,
# Nearest to mother: her, luba, husband, wife, whatsoever, divorced, adult, seventeen,
# Nearest to king: lamp, andromache, zajdel, genealogies, pomerania, omri, kingdom, ahaz,
# Nearest to queen: highness, golden, princess, archdeacon, warden, elizabeth, klux, nota,
# Nearest to prince: pretender, veneto, tsonga, ruthenia, negligence, tabloid, hengest, dukes,
# Nearest to princess: queen, gp, arnulf, sterility, skie, ole, unlockable, mug,
# Nearest to general: southsea, referring, whewell, sugar, yerba, magen, dnestr, flattening,
# Nearest to soldier: wreckage, ouen, composer, eustace, kb, megaman, nourishment, multitudes,
# Nearest to dog: goat, variant, cyclopes, leavitt, porphyry, erectile, uh, breed,
# Nearest to pig: forsythe, outputting, feces, risen, adl, canned, aureus, trees,
# Nearest to cat: gotcha, grape, commonly, grainger, unlucky, romances, blooming, chambers,
# Nearest to mouse: stimuli, deterred, appears, taoists, smegma, jeremy, typify, affectionate,
# Nearest to fish: chondrichthyes, crayfish, reptiles, cucumbers, abbotsford, unconfirmed, sustainable, celera,
# Nearest to bird: reader, predator, spotted, plumage, consanguinity, subgenus, greig, sauropod,
# Nearest to eagle: salamis, saavedra, polynesians, spaceshipone, twig, oversized, paean, keegan,
# Nearest to pigeon: categories, turtle, kista, steller, ursinus, modena, salut, ros,
# Nearest to tree: dreher, constraint, ebcdic, stowed, amaterasu, conclude, changer, simian,
# Nearest to flower: stalk, purple, smell, tes, emptying, embankments, haikai, flowers,
# Nearest to grass: marvellous, courses, findable, ndez, upland, carnivorous, dreamed, pred,
# Nearest to apple: macintosh, distancing, lakewood, decks, beccaria, harrison, released, powerbook,
# Nearest to orange: excitation, logo, white, sabah, leaven, yellow, colors, beagle,
# Nearest to grape: cat, cultivar, framers, kyushu, winkler, chiles, caucasian, deciduous,
# Nearest to red: byproduct, colors, wco, color, glaad, blue, yellow, hoist,
# Nearest to green: purple, bloc, anaconda, tinted, electress, deprogrammings, merle, colours,
# Nearest to yellow: yellowish, colour, colors, pale, color, orange, glasses, shade,
# Nearest to blue: shirt, colored, red, shade, colors, dicke, constellation, wearing,
# Nearest to dark: directorship, joanna, piracy, abundances, stalagmites, murdoch, swingarm, goofy,
# Nearest to sun: magnetosphere, sidereal, venerated, centauri, solar, gravitational, cloud, gravitationally,
# Nearest to earth: surface, dielectrics, radiotelephone, equator, demigod, sidereal, intersputnik, asteroid,
# Nearest to mars: tezuka, rdoba, orbiter, planetary, bambi, tilted, joaquin, probe,
# Nearest to moon: maxfield, mankind, landing, plait, ecliptic, salam, dark, extrasolar,
# Nearest to universe: ugly, cosmology, councils, confront, cosmic, offeror, poissy, accelerators,
# Nearest to water: liters, confessed, bogot, maturity, guericke, layer, acetone, nutrient,
# Nearest to fire: searchers, tabor, aspiration, aikido, dreamer, lawgiver, newsreader, merlot,
# Nearest to stone: stacking, overgrown, barrows, neolithic, decoration, wyoming, vico, biarritz,
# Nearest to run: sld, substitutes, runs, outfielder, disk, pfeiffer, itanium, preinstalled,
# Nearest to walk: robbie, slade, pseudalopex, funnel, elect, gatwick, grieve, tsar,
# Nearest to crawl: functionalities, yachts, clockless, lysis, ailment, restarts, coco, caa,
# Nearest to jump: litre, thigh, freefall, pleasantville, javan, kd, riding, corelli,
# Nearest to jog: funchal, fulfil, enniskillen, cyclops, ursa, republik, radclyffe, strewn,
# Nearest to food: broth, regrowth, meat, dopamine, glaciated, protect, solanaceae, feu,
# Nearest to meal: snack, meals, eat, semple, gorgeous, choy, barn, hyena,
# Nearest to breakfast: cheesemaking, ketchup, coconut, vbscript, crisp, ohms, flour, baseketball,
# Nearest to lunch: rhea, scorecard, cheers, matriarch, trademarked, curious, cooking, devito,
# Nearest to dinner: jute, filmmaker, udall, dream, bun, abstractly, vitamin, pinafore,
# Nearest to meat: pork, cereal, stews, dumplings, food, sabbats, grilled, soup,
# Nearest to rice: tofu, represents, uncooked, ketchup, technician, cuisines, voodoo, mps,
# Nearest to vegetable: marinated, rascal, fruits, harry, desserts, coenzyme, trypomastigotes, butter,
# Nearest to love: songs, delany, me, passion, hamlet, havenco, jule, shame,
# Nearest to hate: awful, accumulates, claimed, miggins, skeptics, rape, warfield, ephraim,
# Nearest to kiss: me, sinners, resume, oshawa, immediate, jelly, bette, lecter,
# Nearest to kill: awash, killing, lusaka, aides, woo, elmo, fatally, nonlinear,
# Nearest to war: obsession, ncos, wars, macbeth, screenname, reestablishing, civil, echoed,
# Nearest to peace: stilwell, oslo, stating, negotiations, agreed, agreement, lecter, carvin,
# Nearest to machine: arbitrator, interpreter, eph, arbitrio, teutonic, trinidad, cronin, bolder,
# Nearest to country: landlocked, camino, rm, servitude, charts, codebreaking, mia, lunokhod,
# Nearest to china: taiwan, yan, ming, xuan, hong, han, chinese, jurchen,
# Nearest to america: fortes, johnstone, journal, brazil, countercultural, amigaone, washington, mccourt,
# Nearest to korean: loanwords, varma, militant, singapore, retroflex, tampa, emmanuelle, levon,
# Nearest to russia: russian, westphalian, soviet, neisse, hopkinson, henryk, lutheranism, brabham,
# Nearest to german: germany, germanic, css, nach, schleicher, ww, writing, gustav,
# Nearest to spain: trophyless, spanish, portugal, unsurprisingly, redonda, jos, peloponnesus, fulcrum,
# Nearest to brazil: militarist, santo, horizonte, slovaks, netherlands, czechs, tans, uruguay,
# Epoch 6/6 Iteration: 26100 Avg. Training loss: 3.9276 0.0946 sec/batch
# Epoch 6/6 Iteration: 26200 Avg. Training loss: 3.9318 0.0898 sec/batch
# Epoch 6/6 Iteration: 26300 Avg. Training loss: 3.9478 0.0911 sec/batch
# Epoch 6/6 Iteration: 26400 Avg. Training loss: 3.9154 0.0912 sec/batch
# Epoch 6/6 Iteration: 26500 Avg. Training loss: 3.9242 0.0910 sec/batch
# Epoch 6/6 Iteration: 26600 Avg. Training loss: 3.9587 0.0914 sec/batch
# Epoch 6/6 Iteration: 26700 Avg. Training loss: 3.8983 0.0905 sec/batch
# Epoch 6/6 Iteration: 26800 Avg. Training loss: 4.0291 0.0901 sec/batch
# Epoch 6/6 Iteration: 26900 Avg. Training loss: 3.9870 0.0903 sec/batch
# Epoch 6/6 Iteration: 27000 Avg. Training loss: 4.0121 0.0902 sec/batch
# Epoch 6/6 Iteration: 27100 Avg. Training loss: 3.9091 0.0911 sec/batch
# Epoch 6/6 Iteration: 27200 Avg. Training loss: 3.9150 0.0910 sec/batch
# Epoch 6/6 Iteration: 27300 Avg. Training loss: 3.9171 0.0904 sec/batch
# Epoch 6/6 Iteration: 27400 Avg. Training loss: 3.8375 0.0905 sec/batch
# Epoch 6/6 Iteration: 27500 Avg. Training loss: 3.9424 0.0907 sec/batch
# Epoch 6/6 Iteration: 27600 Avg. Training loss: 3.9411 0.0901 sec/batch
# Epoch 6/6 Iteration: 27700 Avg. Training loss: 3.9172 0.0902 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE (t-Distributed Stochastic Neighbor Embedding) to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)

# %%
view_int_words = valid_examples

tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[view_int_words, :])

fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(len(view_int_words)):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[view_int_words[idx]], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)

# %% [markdown]
# ### Rui's NOTE
# The plots below does not work, so it shows that for measure and plot similarity, still need to used normalized_embedding

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)

# %%
view_int_words = valid_examples

tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[view_int_words, :])

fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(len(view_int_words)):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[view_int_words[idx]], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
